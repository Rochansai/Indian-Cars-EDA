# %% [markdown]
# **Indian Cars : Data Processing & Visualization**
# ---

# %% [markdown]
# # **Importing Libraries**

# %% [markdown]
# So, inorder to perform anything on the data we must require to import the librarires first and set the diplay view of the dataset.

# %% [markdown]
# This code snippet imports necessary Python libraries, `sets display options for Pandas`, and prepares the environment for data analysis and visualization.

# %%
# Importing required libraries for data analysis and visualization
import pandas as pd                       # Pandas for data manipulation and analysis
import numpy as np                        # NumPy for numerical operations
import matplotlib.pyplot as plt           # Matplotlib for basic plotting
import seaborn as sns                     # Seaborn for statistical data visualization
import plotly.express as px               # Plotly Express for interactive visualizations

# Setting display options for Pandas to show three decimal places for floating-point numbers
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # **Loading Dataset**

# %%
# Display all columns without truncation
pd.set_option('display.max_columns', None)

# Load car-related dataset from URL into 'car' DataFrame
url = 'C:/Users/varun/Dropbox/My PC (LAPTOP-163UJTU7)/Desktop/Required Files/Exploratory Data Analysis/Cars Dataset/cars_ds_final.csv'
cars = pd.read_csv(url, encoding='unicode_escape')

# Display first two rows of the loaded DataFrame
cars.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0      2.000                2.000  RWD (Rear Wheel Drive)
# 1      2.000                2.000  RWD (Rear Wheel Drive)
# 2      2.000                2.000  RWD (Rear Wheel Drive)
# 3      2.000                2.000  RWD (Rear Wheel Drive)
# 4      2.000                2.000  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration Emission_Norm   Engine_Location Fuel_System  \
# 0                In-line         BS IV  Rear, Transverse   Injection
# ...

# %% [markdown]
# The code deletes the 'Unnamed: 0' column from the `'cars'` DataFrame, likely an unnecessary index. <br>The `head(2)` function then displays the first two rows of the updated DataFrame.

# %%
# Remove 'Unnamed: 0' column from 'car' DataFrame
del cars["Unnamed: 0"]

# Display first two rows
cars.head(2)
# Out:
#    Make      Model Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx      Xt      Rs. 2,92,667       624 cc      2.000
# 1  Tata  Nano Genx      Xe      Rs. 2,36,447       624 cc      2.000
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                2.000  RWD (Rear Wheel Drive)                In-line
# 1                2.000  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm   Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type  \
# 0         BS IV  Rear, Transverse   Injection          24 litres    Petrol
# 1         BS IV  Rear, Transverse   Injection          24 litres    Petrol
#
#     Height   Length    Width  Body_Type  Doors    City_Mileage  \
# 0  1652 mm  3164 mm  1750 mm  Hatchback  5.000  ?23.6 km/litre
# 1  1652 mm  3164 mm  1750 mm  Hatchback  5.000  ?23.6 km/litre
#
#   Highway_Mileage ARAI_Certified_Mileage ARAI_Certified_Mileage_for_CNG  \
# ...

# %% [markdown]
# # **Preliminary Data Inspection**

# %% [markdown]
# To perform any operation on the dataset, we need to get understand the data of the dataset.

# %% [markdown]
# Showcasing the data types of each column in the '`cars`' DataFrame.

# %%
# Display data types of columns in the 'cars' DataFrame
cars.dtypes
# Out:
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
# Displacement          object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 140, dtype: object

# %% [markdown]
# Detailed information about the '`cars`' DataFrame, including *data types* and *memory usage*

# %%
 # Display concise information about 'cars' DataFrame
cars.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 140 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    Make                                       object
#  1    Model                                      object
#  2    Variant                                    object
#  3    Ex-Showroom_Price                          object
#  4    Displacement                               object
#  5    Cylinders                                  float64
#  6    Valves_Per_Cylinder                        float64
#  7    Drivetrain                                 object
#  8    Cylinder_Configuration                     object
#  9    Emission_Norm                              object
#  10   Engine_Location                            object
#  11   Fuel_System                                object
#  12   Fuel_Tank_Capacity                         object
# ...

# %% [markdown]
# checking the number of rows and columns

# %%
cars.shape
# Out:
# (1276, 140)

# %% [markdown]
# Using `cars.describe()` to generate descriptive statistics for the numerical columns in the '`cars`' DataFrame.

# %%
# Generate descriptive statistics for numerical columns
cars.describe()
# Out:
#        Cylinders  Valves_Per_Cylinder    Doors  Seating_Capacity  \
# count   1210.000             1174.000 1272.000          1270.000
# mean       4.381                3.978    4.550             5.270
# std        1.661                0.834    0.748             1.145
# min        2.000                1.000    2.000             2.000
# 25%        4.000                4.000    4.000             5.000
# 50%        4.000                4.000    5.000             5.000
# 75%        4.000                4.000    5.000             5.000
# max       16.000               16.000    5.000            16.000
#
#        Number_of_Airbags  USB_Ports
# count           1141.000     29.000
# mean               3.787      1.793
# std                2.522      0.774
# min                1.000      1.000
# 25%                2.000      1.000
# 50%                2.000      2.000
# 75%                6.000      2.000
# max               14.000      3.000

# %% [markdown]
# # **Data Cleaning and Trimming**

# %% [markdown]
# Modifying each and every column accordingly to get a smooth analysis in data vizualization.

# %% [markdown]
# ### 1. Handling the large missing values

# %% [markdown]
# Now, we will calculate and display the percentage of missing values for each column in the '`cars`' DataFrame. <br>This information helps in understanding the completeness of the dataset and identifies columns with **missing data**.

# %%
# Calculate the percentage of missing values for each column in 'car' DataFrame
row_size = cars.shape[0]
for i in cars.columns :
  if cars[i].isnull().sum() > 0 :
    print(i,"-------",(cars[i].isnull().sum() / row_size ) * 100)
# Out:
# Make ------- 5.877742946708464
# Displacement ------- 0.9404388714733543
# Cylinders ------- 5.172413793103448
# Valves_Per_Cylinder ------- 7.993730407523511
# Drivetrain ------- 0.54858934169279
# Cylinder_Configuration ------- 1.018808777429467
# Emission_Norm ------- 0.8620689655172413
# Engine_Location ------- 3.369905956112853
# Fuel_System ------- 0.6269592476489028
# Fuel_Tank_Capacity ------- 5.407523510971787
# Height ------- 0.07836990595611285
# Width ------- 0.9404388714733543
# Body_Type ------- 0.4702194357366771
# Doors ------- 0.3134796238244514
# City_Mileage ------- 43.495297805642636
# Highway_Mileage ------- 62.695924764890286
# ARAI_Certified_Mileage ------- 8.934169278996865
# ARAI_Certified_Mileage_for_CNG ------- 97.88401253918495
# Kerb_Weight ------- 28.605015673981192
# Gears ------- 8.22884012539185
# Ground_Clearance ------- 22.648902821316614
# Front_Brakes ------- 1.9592476489028214
# Rear_Brakes ------- 1.9592476489028214
# ...

# %% [markdown]
#  checking for and printing the number of duplicate rows in the '`cars`' DataFrame, helping to identify and address potential data duplication issues.

# %%
# check for duplicate rows in 'cars' DataFrame
cars.duplicated().sum()
# Out:
# 9

# %% [markdown]
# Now we will observe the current `shape` of the '`car`' DataFrame, indicating the number of rows and columns after the previous operations.

# %%
 # Display the current shape (rows, columns) of the 'car' DataFrame
cars.shape
# Out:
# (1276, 140)

# %% [markdown]
# In this step, removing columns from the '`cars`' DataFrame that have more than **70% missing values**, excluding the '`ARAI_Certified_Mileage_for_CNG`' column for future reference.

# %%
# Remove columns with more than 70% missing values, excluding 'ARAI_Certified_Mileage_for_CNG'

row_size = cars.shape[0]
for i in cars.columns :
  if i != 'ARAI_Certified_Mileage_for_CNG' :
    if cars[i].isnull().sum() / row_size * 100 > 70 :
      cars.drop(columns = [i], inplace = True)

# %% [markdown]
# Now, we observe the shape of the '`cars`' DataFrame **after removing** columns with more than 70% missing values (excluding '`ARAI_Certified_Mileage_for_CNG`').

# %%
 # Display the updated shape (rows, columns) of the 'cars' DataFrame
cars.shape
# Out:
# (1276, 116)

# %% [markdown]
# ### 2. Processing `Make`, `Model` and `Variant` Dataset

# %% [markdown]
# Here, we fill the missing values in the '`Make`' column with the corresponding values from the '`Model`' column, updating the '`cars`' DataFrame in place.

# %%
# Fill missing values in 'Make' column with correspondng 'Model' values
cars['Make'].fillna(cars['Model'], inplace = True)

# %% [markdown]
# Now, we inspect the unique values in the '`Make`' column of the '`cars`' DataFrame to understand the variety of car makes present in the dataset.

# %%
cars['Make'].unique()
# Displays the unique values in the 'Make' column of the dataset
# Out:
# array(['Tata', 'Datsun', 'Renault', 'Maruti Suzuki', 'Hyundai', 'Premier',
#        'Toyota', 'Nissan', 'Volkswagen', 'Ford', 'Mahindra', 'Fiat',
#        'Honda', 'Jeep', 'Isuzu', 'Skoda', 'Audi', 'Mercedes-Benz B-Class',
#        'Mercedes-Benz Cla-Class', 'Dc', 'Mini', 'Volvo', 'Jaguar', 'Bmw',
#        'Land Rover', 'Mercedes-Benz E-Class Cabriolet', 'Porsche',
#        'Mercedes-Benz Gls', 'Lexus', 'Mercedes-Benz S-Class', 'Maserati',
#        'Mercedes-Benz G-Class', 'Mercedes-Benz Maybach',
#        'Mercedes-Benz S-Class Cabriolet', 'Lamborghini', 'Bentley',
#        'Ferrari', 'Aston Martin', 'Rolls-Royce Ghost Series Ii',
#        'Rolls-Royce Wraith', 'Rolls-Royce Cullinan',
#        'Rolls-Royce Phantom Coupe', 'Bugatti', 'Bajaj', 'Icml', 'Force',
#        'Mg', 'Kia', 'Land Rover Rover', 'Mercedes-Benz E-Class',
#        'Mercedes-Benz C-Class Cabriolet', 'Mercedes-Benz V-Class',
#        'Mercedes-Benz E-Class All Terrain', 'Mercedes-Benz Amg-Gt',
# ...

# %% [markdown]
# Here, we standardize the '`Make`' values in the '`cars`' DataFrame by **replacing or updating** specific entries for consistency. This ensures a uniform representation of car makes in the dataset.

# %%
# Standardize 'Make' values in the 'cars' DataFrame
cars.loc[cars["Make"].str.contains('Mercedes-Benz', na = False), 'Make'] = 'Mercedes-Benz'
cars.loc[cars["Make"].str.contains('Rolls-Royce', na = False), 'Make'] = 'Rolls-Royce'
cars.loc[cars["Make"].str.contains("G0+",na = False), "Make"] = "Datsun"
cars.loc[cars["Make"].str.contains("Maruti Suzuki R", na = False), "Make"] = "Maruti suzuki"
cars["Make"] = cars["Make"].str.replace("Land Rover Rover", "Land Rover")

# %% [markdown]
# Now, we take a look at a random sample of 5 rows from the '`cars`' DataFrame to get an overview of the data after the previous transformations.

# %%
cars.sample(5)
# Display a random sample of 5 rows from the 'cars' DataFrame
# Out:
#                Make       Model                       Variant  \
# 1249          Skoda     Octavia              Onyx 1.8 Tsi Dsg
# 814            Audi          Q7  40 Tfsi Quattro Premium Plus
# 418   Maruti Suzuki       Swift                       Vxi Amt
# 0              Tata   Nano Genx                            Xt
# 415        Mahindra  Kuv100 Nxt              K2 6Str Cng Taxi
#
#      Ex-Showroom_Price Displacement  Cylinders  Valves_Per_Cylinder  \
# 1249     Rs. 19,99,599      1798 cc      4.000                4.000
# 814      Rs. 69,21,500      1984 cc      6.000                4.000
# 418       Rs. 6,66,000      1197 cc      4.000                4.000
# 0         Rs. 2,92,667       624 cc      2.000                2.000
# 415       Rs. 5,42,913      1198 cc      3.000                4.000
#
#                    Drivetrain Cylinder_Configuration Emission_Norm  \
# 1249  FWD (Front Wheel Drive)                In-line         BS IV
# ...

# %% [markdown]
# ### 3. Processing `Ex-Showroom_Price` and `Displacement` Dataset

# %%
# Display specific columns 'Ex-Showroom_Price' and 'Displacement' from the 'cars' DataFrame

specific_1 = ["Ex-Showroom_Price","Displacement"]
print(cars[specific_1].head())
# Out:
#   Ex-Showroom_Price Displacement
# 0      Rs. 2,92,667       624 cc
# 1      Rs. 2,36,447       624 cc
# 2      Rs. 2,96,661       624 cc
# 3      Rs. 3,34,768       624 cc
# 4      Rs. 2,72,223       624 cc

# %% [markdown]
# Here, we clean the '`Ex-Showroom_Price`' column by removing **non-numeric** characters, rename it to '`Ex-Showroom_Price_INR`', and convert the values to **integers** in the '`cars`' DataFrame.

# %%
# Clean 'Ex-Showroom_Price' column in 'cars' DataFrame
cars['Ex-Showroom_Price'] = cars["Ex-Showroom_Price"].replace(r'\D','', regex = True)

# Rename the cleaned column to 'Ex-Showroom_Price_INR'
cars.rename(columns = {'Ex-Showroom_Price' : 'Ex-Showroom_Price_INR'}, inplace = True)

# convert 'Ex-Showroom_Price_INR' column to integer type
cars['Ex-Showroom_Price_INR'] = cars["Ex-Showroom_Price_INR"].astype(int)

# %% [markdown]
# This code cleans the '`Displacement`' column by **removing non-numeric** characters, renames it to '`Displacement_cc`', and converts the values to **float** in the '`cars`' DataFrame.

# %%
# clean 'Displacement' column in 'cars' DataFrame
cars['Displacement'] = cars['Displacement'].replace(r'\D','', regex = True)

# Rename the cleaned column to 'Displacement_cc'
cars.rename(columns = {"Displacement" : "Displacement_cc"}, inplace = True)

# convert "Displacement_cc" column to float type
cars["Displacement_cc"] = cars["Displacement_cc"].astype(float)

# %% [markdown]
# Here, we print the first few rows of specific columns, '`Ex-Showroom_Price_INR`' and '`Displacement_cc`', from the '`cars`' DataFrame to check the cleaning clarity.

# %%
# Display specific columns 'Ex-Showroom_Price_INR' and 'Displacement_cc' from the 'car' DataFrame
specific_1 = ["Ex-Showroom_Price_INR","Displacement_cc"]
print(cars[specific_1].head())
# Out:
#    Ex-Showroom_Price_INR  Displacement_cc
# 0                 292667          624.000
# 1                 236447          624.000
# 2                 296661          624.000
# 3                 334768          624.000
# 4                 272223          624.000

# %% [markdown]
# ###4. Ensuring Datatypes of `Cylinders` and `Valves_Per_Cylinder` Dataset

# %% [markdown]
# Here, we convert the '`Cylinders`' and '`Valves_Per_Cylinder`' column to float type in the '`cars`' DataFrame.

# %%
# Convert 'Cylinders' column to float type in 'cars' DataFrame
cars['Cylinders'] = cars['Cylinders'].astype(float)

# %%
# Convert 'Valves_Per_Cylinder' column to float type in 'cars' DataFrame
cars["Valves_Per_Cylinder"] = cars["Valves_Per_Cylinder"].astype(float)

# %% [markdown]
# ###5. Processing `Drivetrain` Dataset

# %% [markdown]
# Now, we examine the unique values in the '`Drivetrain`' column of the '`cars`' DataFrame to understand the different drivetrain configurations present in the dataset.

# %%
cars["Drivetrain"].unique()
# Out:
# array(['RWD (Rear Wheel Drive)', 'FWD (Front Wheel Drive)',
#        'AWD (All Wheel Drive)', '4WD', nan], dtype=object)

# %% [markdown]
# This code cleans the '`Drivetrain`' column in the '`cars`' DataFrame by removing specific patterns like '`(Rear Wheel Drive)`', '`(Front Wheel Drive)`', and '`(All Wheel Drive)`'.

# %%
# Clean 'Drivetrain' column in 'car' DataFrame
cars['Drivetrain'] = cars['Drivetrain'].str.replace(r'\(Rear Wheel Drive\)', '', regex=True)
cars['Drivetrain'] = cars['Drivetrain'].str.replace(r'\(Front Wheel Drive\)', '', regex=True)
cars['Drivetrain'] = cars['Drivetrain'].str.replace(r'\(All Wheel Drive\)', '', regex=True)

# %% [markdown]
# Now, we inspect the unique values in the cleaned '`Drivetrain`' column of the '`cars`' DataFrame to observe the drivetrain configurations after the cleaning process.

# %%
# Display unique values in the cleaned 'Drivetrain' column of the 'cars' DataFrame
cars["Drivetrain"].unique()
# Out:
# array(['RWD ', 'FWD ', 'AWD ', '4WD', nan], dtype=object)

# %% [markdown]
# ###6. Processing `Emission_Norm` and `Engine_Location` Dataset

# %% [markdown]
# Here, we observe the unique values in the '`Emission_Norm`' column of the '`cars`' DataFrame to understand the different emission norms present in the dataset.

# %%
# Display unique values in the 'Emission_Norm' column of the 'cars' DataFrame
cars["Emission_Norm"].unique()
# Out:
# array(['BS IV', 'BS 6', nan, 'BS III', 'BS VI'], dtype=object)

# %% [markdown]
# In this step, we replace '`BS 6`' with '`BS VI`' in the '`Emission_Norm`' column of the '`cars`' DataFrame for consistency.

# %%
# Update 'Emission_Norm', replacing 'BS 6' with 'BS VI
cars["Emission_Norm"] = cars["Emission_Norm"].str.replace("BS 6","BS VI")

# %% [markdown]
# Now, we examine the unique values in the updated '`Emission_Norm`' column of the '`cars`' DataFrame to confirm the replacement of '`BS 6`' with '`BS VI`'.

# %%
# Display unique values in the updated 'Emission_Norm' column of the 'cars' DataFrame
cars['Emission_Norm'].unique()
# Out:
# array(['BS IV', 'BS VI', nan, 'BS III'], dtype=object)

# %% [markdown]
# Here, we explore the unique values in the '`Engine_Location`' column of the '`cars`' DataFrame to understand the various engine locations recorded in the dataset.

# %%
# Display unique values in the 'Engine_Location' column of the 'cars' DataFrame
cars["Engine_Location"].unique()
# Out:
# array(['Rear, Transverse', 'Front, Transverse', 'Front, Longitudinal',
#        nan, 'Rear Mid, Transverse', 'Mid, Longitudinal',
#        'Mid, Transverse', 'Rear, Longitudinal'], dtype=object)

# %% [markdown]
# This code modifies the '`Engine_Location`' column in the '`cars`' DataFrame by replacing '`, `' with '` - `' for consistency and clarity.

# %%
# Update 'Engine_Location' replacing ', ' with ' - '
cars["Engine_Location"] = cars["Engine_Location"].str.replace(", "," - ")

# %% [markdown]
# Now, we examine the unique values in the updated '`Engine_Location`' column of the '`cars`' DataFrame after the replacement operation.

# %%
 # Display unique values in the updated 'Engine_Location' column of the 'cars' DataFrame
cars["Engine_Location"].unique()
# Out:
# array(['Rear - Transverse', 'Front - Transverse', 'Front - Longitudinal',
#        nan, 'Rear Mid - Transverse', 'Mid - Longitudinal',
#        'Mid - Transverse', 'Rear - Longitudinal'], dtype=object)

# %% [markdown]
# ###7. Processing `Fuel_Tank_Capacity`, `Height`, `Length`, `Width`, `Kerb_Weight` and `Ground_Clearance` Dataset

# %% [markdown]
# Here, we print the first few rows of the '`Fuel_Tank_Capacity`' column from the '`cars`' DataFrame to inspect the fuel tank capacity values.

# %%
# Display the 'Fuel_Tank_Capacity' column from the 'cars' DataFrame
print(cars["Fuel_Tank_Capacity"].head())
# Out:
# 0    24 litres
# 1    24 litres
# 2    15 litres
# 3    24 litres
# 4    24 litres
# Name: Fuel_Tank_Capacity, dtype: object

# %% [markdown]
# This code cleans the '`Fuel_Tank_Capacity`' column by removing non-numeric characters, renames it to '`Fuel_Tank_Capacity_litres`', and converts the values to **float** in the '`cars`' DataFrame.

# %%
# Clean 'Fuel_Tank_Capacity' column in 'cars' DataFrame
cars["Fuel_Tank_Capacity"] = cars["Fuel_Tank_Capacity"].replace(r"\D","", regex = True)

# Rename the cleaned column to 'Fuel_Tank_Capacity_litres'
cars.rename(columns = {"Fuel_Tank_Capacity" : "Fuel_Tank_Capacity_litres"}, inplace = True)

# Convert 'Fuel_Tank_Capacity_litres' column to float type
cars["Fuel_Tank_Capacity_litres"] = cars["Fuel_Tank_Capacity_litres"].astype(float)

# %%
# Display the cleaned 'Fuel_Tank_Capacity_litres' column from the 'cars' DataFrame

print(cars["Fuel_Tank_Capacity_litres"].head())
# Out:
# 0   24.000
# 1   24.000
# 2   15.000
# 3   24.000
# 4   24.000
# Name: Fuel_Tank_Capacity_litres, dtype: float64

# %% [markdown]
# Here, we print the first few rows of selected dimensions ('`Height`', '`Length`', '`Width`', '`Kerb_Weight`', '`Ground_Clearance`') from the '`cars`' DataFrame for inspection.

# %%
# Display selected dimensions - 'Height', 'Length', 'Width', 'Kerb_Weight', 'Ground_Clearance'
dimension = ["Height", "Length", "Width", "Kerb_Weight", "Ground_Clearance"]
print(cars[dimension].head())
# Out:
#     Height   Length    Width Kerb_Weight Ground_Clearance
# 0  1652 mm  3164 mm  1750 mm      660 kg           180 mm
# 1  1652 mm  3164 mm  1750 mm      725 kg           180 mm
# 2  1652 mm  3164 mm  1750 mm      710 kg           180 mm
# 3  1652 mm  3164 mm  1750 mm      725 kg           180 mm
# 4  1652 mm  3164 mm  1750 mm      725 kg           180 mm

# %% [markdown]
# This code cleans and standardizes various dimensions columns in the '`cars`' DataFrame, renaming columns to reflect units and converting them to float type for consistency.

# %%
# Clean and standardize dimensions in 'car' DataFrame
cars['Height'] = cars['Height'].replace(r'\D', '', regex=True)
cars['Length'] = cars['Length'].replace(r'\D', '', regex=True)
cars['Width'] = cars['Width'].replace(r'\D', '', regex=True)
cars['Kerb_Weight'] = cars['Kerb_Weight'].replace(r'\D', '', regex=True)
cars['Ground_Clearance'] = cars['Ground_Clearance'].replace(r'\D', '', regex=True)

# Rename columns to reflect units and data type
cars.rename(columns={'Height': 'Height_mm','Length': 'Length_mm','Width': 'Width_mm'}, inplace=True)
cars.rename(columns={'Kerb_Weight': 'Kerb_Weight_kg','Ground_Clearance':'Ground_Clearance_mm'}, inplace=True)

# Convert cleaned columns to float type
cars['Height_mm'] = cars['Height_mm'].astype(float)
cars['Length_mm'] = cars['Length_mm'].astype(float)
cars['Width_mm'] = cars['Width_mm'].astype(float)
cars['Kerb_Weight_kg'] = cars['Kerb_Weight_kg'].astype(float)
cars['Ground_Clearance_mm'] = cars['Ground_Clearance_mm'].astype(float)

# %% [markdown]
# Here, we display the cleaned and standardized dimensions ('`Height_mm`', '`Length_mm`', '`Width_mm`', '`Kerb_Weight_kg`', '`Ground_Clearance_mm`') from the '`cars`' DataFrame for initial inspection.

# %%
# Display cleaned and standardized dimensions from the 'car' DataFrame
dimension = ['Height_mm', 'Length_mm', 'Width_mm', 'Kerb_Weight_kg', 'Ground_Clearance_mm']
cars[dimension].head()
# Out:
#    Height_mm  Length_mm  Width_mm  Kerb_Weight_kg  Ground_Clearance_mm
# 0   1652.000   3164.000  1750.000         660.000              180.000
# 1   1652.000   3164.000  1750.000         725.000              180.000
# 2   1652.000   3164.000  1750.000         710.000              180.000
# 3   1652.000   3164.000  1750.000         725.000              180.000
# 4   1652.000   3164.000  1750.000         725.000              180.000

# %% [markdown]
# ###8. Processing `Body_Type`, `Gears`, and `Body_Type` Dataset

# %% [markdown]
# Now, we explore the unique values in the '`Body_Type`' column of the '`cars`' DataFrame to understand the different types of car bodies recorded in the dataset.

# %%
 # Display unique values in the 'Body_Type' column of the 'car' DataFrame

cars["Body_Type"].unique()
# Out:
# array(['Hatchback', 'MPV', 'MUV', 'SUV', 'Sedan', 'Crossover', nan,
#        'Coupe', 'Convertible', 'Sports, Hatchback', 'Sedan, Coupe',
#        'Sports', 'Crossover, SUV', 'SUV, Crossover', 'Sedan, Crossover',
#        'Sports, Convertible', 'Pick-up', 'Coupe, Convertible'],
#       dtype=object)

# %% [markdown]
# Here, we show the count of each unique value in the '`Gears`' column of the '`cars`' DataFrame, providing insights into the distribution of gear types in the dataset.

# %%
# Display the count of each unique value in the 'Gears' column of the 'car' DataFrame

cars["Gears"].value_counts()
# Out:
# Gears
# 5                              614
# 6                              233
# 8                              139
# 7                              137
# 9                               30
# 4                               16
# 7 Dual Clutch                    1
# Single Speed Reduction Gear      1
# Name: count, dtype: int64

# %% [markdown]
# This code updates and converts the '`Gears`' column in the '`cars`' DataFrame, replacing specific values and converting the column to float type. <br>The count of each unique value in the updated '`Gears`' column is then displayed.

# %%
# Update and convert 'Gears' column in 'cars' DataFrame
cars["Gears"] = cars["Gears"].replace({'Single Speed Reduction Gear' : '1', '7 Dual Clutch' : '7'})
cars["Gears"] = cars["Gears"].astype(float)

# Display the count of each unique value in the updated 'Gears' column
cars['Gears'].value_counts()
# Out:
# Gears
# 5.000    614
# 6.000    233
# 8.000    139
# 7.000    138
# 9.000     30
# 4.000     16
# 1.000      1
# Name: count, dtype: int64

# %% [markdown]
# This code modifies the 'Body_Type' column in the 'cars' DataFrame by replacing ', ' with '-' for consistency and clarity.

# %%
# Update 'Body_Type', replacing ', ' with '-'
cars["Body_Type"] = cars["Body_Type"].str.replace(", ","-")

# %% [markdown]
# Now, we examine the unique values in the updated '`Body_Type`' column of the '`cars`' DataFrame after the replacement operation.

# %%
# Display unique values in the updated 'Body_Type' column of the 'cars' DataFrame
cars["Body_Type"].unique()
# Out:
# array(['Hatchback', 'MPV', 'MUV', 'SUV', 'Sedan', 'Crossover', nan,
#        'Coupe', 'Convertible', 'Sports-Hatchback', 'Sedan-Coupe',
#        'Sports', 'Crossover-SUV', 'SUV-Crossover', 'Sedan-Crossover',
#        'Sports-Convertible', 'Pick-up', 'Coupe-Convertible'], dtype=object)

# %% [markdown]
# ###9. Processing `Mileage` Datasets

# %% [markdown]
# Here, we count the number of missing values in the '`ARAI_Certified_Mileage`' column of the '`cars`' DataFrame to assess the extent of missing mileage information.

# %%
# Count the number of missing values in the 'ARAI_Certified_Mileage' column of the 'cars' DataFrame
cars['ARAI_Certified_Mileage'].isnull().sum()
# Out:
# 114

# %% [markdown]
# This code fills missing values in the '`ARAI_Certified_Mileage`' column with the corresponding '`Highway_Mileage`' values for **non-CNG vehicles** in the '`cars`' DataFrame.

# %%
# Fill missing values in 'ARAI_Certified_Mileage' with 'Highway_Mileage' for non-CNG vehicles in 'cars' DataFrame

cars.loc[cars["Fuel_Type"] != 'CNG', "ARAI_Certified_Mileage"] = cars["ARAI_Certified_Mileage"].fillna(cars["Highway_Mileage"])

# %% [markdown]
# Now, we verify the number of missing values in the '`ARAI_Certified_Mileage`' column of the '`cars`' DataFrame after the fill operation.

# %%
# Re-check the number of missing values in the 'ARAI_Certified_Mileage' column of the 'cars' DataFrame
cars["ARAI_Certified_Mileage"].isnull().sum()
# Out:
# 101

# %% [markdown]
# Here, we explore the unique values in the '`ARAI_Certified_Mileage`' column of the '`cars`' DataFrame to understand the variety of ARAI certified mileage values present in the dataset.

# %%
# Display unique values in the 'ARAI_Certified_Mileage' column of the 'cars' DataFrame
cars["ARAI_Certified_Mileage"].unique()
# Out:
# array(['23.6 km/litre', nan, '21.9 km/litre', '25.17 km/litre',
#        '22.5 km/litre', '23 km/litre', '23.01 km/litre', '24.04 km/litre',
#        '15 km/litre', '24.07 km/litre', '20.1 km/litre', '23.1 km/litre',
#        '20.3 km/litre', '24 km/litre', '20.89 km/litre', '20.5 km/litre',
#        '16 km/litre', '23.7 km/litre', '18.16 km/litre', '23.59 km/litre',
#        '18.97 km/litre', '19.49 km/litre', '22.95 km/litre',
#        '17.57 km/litre', '15.7 km/litre', '20.14 km/litre', '20 km/litre',
#        '28.4 km/litre', '22 km/litre', '18.6 km/litre', '22.54 km/litre',
#        '18.15 km/litre', '25.35 km/litre', '20.4 km/litre',
#        '25.4 km/litre', '18.78 km/litre', '17.21 km/litre',
#        '19.91 km/litre', '24.4 km/litre', '19 km/litre', '21.66 km/litre',
#        '21.73 km/litre', '26.1 km/litre', '19.4 km/litre',
#        '16.78 km/litre', '17.71 km/litre', '20.08 km/litre',
#        '17.1 km/litre', '23.87 km/litre', '21.01 km/litre',
# ...

# %% [markdown]
# This code cleans and standardizes the '`ARAI_Certified_Mileage`' column in the '`cars`' DataFrame, addressing units and replacing specific incorrect values. <br>The cleaned column is then renamed to '`ARAI_Certified_Mileage_kmpl`'.

# %%
# Clean and standardize 'ARAI_Certified_Mileage' column in 'cars' DataFrame
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].str.replace(r'\s*km/litre', '', regex=True)
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].str.replace('9.8-10.0', '10.0')
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].str.replace('22.4-21.9', '22.4')
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].str.replace(r'\s*kmpl', '', regex=True)

cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].astype(float)

# Replace specific incorrect values
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].replace(142.0, 14.2)
cars['ARAI_Certified_Mileage'] = cars['ARAI_Certified_Mileage'].replace(1449.0, 14.49)

# Rename the cleaned column to 'ARAI_Certified_Mileage_kmpl'
cars.rename(columns={'ARAI_Certified_Mileage': 'ARAI_Certified_Mileage_kmpl'}, inplace=True)

# %% [markdown]
# Now, we explore the unique values in the cleaned '`ARAI_Certified_Mileage_kmpl`' column of the '`cars`' DataFrame to observe the standardized ARAI certified mileage values.

# %%
cars["ARAI_Certified_Mileage_kmpl"].unique()
# Out:
# array([23.6 ,   nan, 21.9 , 25.17, 22.5 , 23.  , 23.01, 24.04, 15.  ,
#        24.07, 20.1 , 23.1 , 20.3 , 24.  , 20.89, 20.5 , 16.  , 23.7 ,
#        18.16, 23.59, 18.97, 19.49, 22.95, 17.57, 15.7 , 20.14, 20.  ,
#        28.4 , 22.  , 18.6 , 22.54, 18.15, 25.35, 20.4 , 25.4 , 18.78,
#        17.21, 19.91, 24.4 , 19.  , 21.66, 21.73, 26.1 , 19.4 , 16.78,
#        17.71, 20.08, 17.1 , 23.87, 21.01, 19.56, 18.2 , 27.3 , 16.3 ,
#        13.8 , 12.35, 12.05, 17.06, 14.4 , 19.5 , 18.3 , 13.7 , 18.19,
#        20.38, 19.2 , 14.81, 15.04, 17.9 , 10.  , 15.73, 16.9 , 21.15,
#        14.59, 16.47, 11.  , 13.12, 19.33, 14.11, 18.56, 13.57, 13.38,
#        11.24, 13.  , 12.8 ,  8.61,  7.4 , 11.6 , 12.  , 11.13, 18.  ,
#        10.8 , 17.66, 11.86,  7.96, 13.5 ,  7.8 , 14.  ,  7.9 , 10.63,
#         6.71,  8.6 ,  9.  ,  8.77, 17.3 ,  7.29, 10.2 ,  9.5 , 22.4 ,
#        22.8 ,  5.95, 35.  , 22.05, 21.4 , 21.7 , 19.77, 25.32, 25.2 ,
# ...

# %% [markdown]
# Here, we inspect the unique values in the '`ARAI_Certified_Mileage_for_CNG`' column of the '`cars`' DataFrame to understand the ARAI certified mileage values for CNG-powered vehicles.

# %%
# Display unique values in the 'ARAI_Certified_Mileage_for_CNG' column of the 'car' DataFrame
cars["ARAI_Certified_Mileage_for_CNG"].unique()
# Out:
# array([nan, '36 km/kg', '20 km/kg', '32.26 km/kg', '31.76 km/kg',
#        '30.48 km/kg', '25 km/kg', '26.6 km/kg', '20.5 km/kg',
#        '20.4 km/kg', '43 km/kg', '31.79 km/kg', '18.9 km/kg',
#        '14.16 km/kg', '13.96 km/kg', '10.8 km/kg', '33.54 km/kg'],
#       dtype=object)

# %% [markdown]
# This code cleans and standardizes the '`ARAI_Certified_Mileage_for_CNG`' column in the '`cars`' DataFrame, addressing units. The cleaned column is then renamed to '`ARAI_Certified_Mileage_for_CNG_kmpkg`'.

# %%
# Clean and standardize 'ARAI_Certified_Mileage_for_CNG' column in 'cars' DataFrame
cars['ARAI_Certified_Mileage_for_CNG'] = cars['ARAI_Certified_Mileage_for_CNG'].str.replace(r'\s*km/kg', '', regex=True)
cars['ARAI_Certified_Mileage_for_CNG'] = cars['ARAI_Certified_Mileage_for_CNG'].astype(float)

# Rename the cleaned column to 'ARAI_Certified_Mileage_for_CNG_kmpkg'
cars.rename(columns={'ARAI_Certified_Mileage_for_CNG': 'ARAI_Certified_Mileage_for_CNG_kmpkg'}, inplace=True)

# %% [markdown]
# Now, we explore the unique values in the cleaned '`ARAI_Certified_Mileage_for_CNG_kmpkg`' column of the '`cars`' DataFrame to observe the standardized ARAI certified mileage values for CNG-powered vehicles.

# %%
# Display unique values in the cleaned 'ARAI_Certified_Mileage_for_CNG_kmpkg'
cars["ARAI_Certified_Mileage_for_CNG_kmpkg"].unique()
# Out:
# array([  nan, 36.  , 20.  , 32.26, 31.76, 30.48, 25.  , 26.6 , 20.5 ,
#        20.4 , 43.  , 31.79, 18.9 , 14.16, 13.96, 10.8 , 33.54])

# %% [markdown]
# This line of code fills missing values in the '`ARAI_Certified_Mileage_kmpl`' column with values from the corresponding '`ARAI_Certified_Mileage_for_CNG_kmpkg`' column in the 'cars' DataFrame.

# %%
# Fill missing values in 'ARAI_Certified_Mileage_kmpl' with values from 'ARAI_Certified_Mileage_for_CNG_kmpkg'
cars['ARAI_Certified_Mileage_kmpl'].fillna(cars['ARAI_Certified_Mileage_for_CNG_kmpkg'], inplace=True)

# %% [markdown]
# This code removes the '`City_Mileage`', `'ARAI_Certified_Mileage_for_CNG_kmpkg'` and '`Highway_Mileage`' columns from the '`cars`' DataFrame, as they are no longer needed.

# %%
# Drop columns 'City_Mileage' and 'Highway_Mileage' from 'cars' DataFrame
mileage_drop = ['City_Mileage', 'Highway_Mileage','ARAI_Certified_Mileage_for_CNG_kmpkg']
cars.drop(columns=mileage_drop, inplace=True)

# %% [markdown]
# ###10. Processing `Suspension` Datasets

# %% [markdown]
# Here, we examine the unique values in the '`Front_Suspension`' column of the '`cars`' DataFrame to understand the different front suspension configurations recorded in the dataset.

# %%
 # Display unique values in the 'Front_Suspension' column of the 'cars' DataFrame
cars["Front_Suspension"].unique()
# Out:
# array(['Independent, Lower Wishbone, McPherson Strut with gas filled dampers and anti-roll bar',
#        'Double Pivot Arm',
#        'Mac Pherson strut with Lower Transverse link, coil spring',
#        'MacPherson Struts With Lower Transverse Links',
#        'McPherson struts', 'McPherson Strut',
#        'Gas Filled Mc Pherson Strut',
#        'MacPherson Strut with anti-roll bar',
#        'Macpherson strut with Coil Spring', nan, 'Mc Pherson Strut',
#        'MacPherson Strut', 'Mc Pherson Struct',
#        'Independent, Lower Wishbone, Mcpherson Strut with coil spring',
#        'Independent Lower Wishbone, McPherson Strut with coil Spring',
#        'McPherson strut & coil spring', 'Mc Pherson-strut',
#        'Dual-path McPherson strut with coil spring and anti-roll bar',
#        'McPherson strut with coil spring',
#        'McPherson strut with stabiliser bar',
#        'MacPherson Strut with Staboilizer Bar', 'Independent McPherson',
# ...

# %% [markdown]
# This code updates the '`Front_Suspension`' column in the '`cars`' DataFrame, standardizing various suspension types for consistency and clarity.

# %%
# Update 'Front_Suspension' column in 'car' DataFrame with standardized suspension types
cars.loc[cars['Front_Suspension'].str.contains('MacPherson|Mac Pherson|Mc Pherson|McPherson|Macpherson|Mcpherson', na=False), 'Front_Suspension'] = 'MacPherson Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Double Wishbone|Double wishbone|double-wishbone|double wishbone|Double wish-bone', na=False), 'Front_Suspension'] = 'Double Wishbone Suspension'
cars.loc[cars['Front_Suspension'].str.contains('link|Link', na=False), 'Front_Suspension'] = 'Multi Link Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Adaptive|adaptive', na=False), 'Front_Suspension'] = 'Adaptive Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Leaf spring|leaf spring|Leaf Spring', na=False), 'Front_Suspension'] = 'Leaf Spring Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Air|air|AIRMATIC', na=False), 'Front_Suspension'] = 'Air Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Damper|damper|damping|CONTROL', na=False), 'Front_Suspension'] = 'Damper Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Independent|independent', na=False), 'Front_Suspension'] = 'Independent Suspension'
cars.loc[cars['Front_Suspension'].str.contains('Double joint|Double-Joint', na=False), 'Front_Suspension'] = 'Double Joint Suspension'
cars.loc[cars['Front_Suspension'].str.contains('single joint ', na=False), 'Front_Suspension'] = 'Single Joint Suspension'
cars.loc[cars['Front_Suspension'].str.contains('MacPherson|Double Wishbone|Multi Link|Adaptive|Leaf Spring|Air|Damper|Independent|Double', na=False), 'Front_Suspension'] = 'Aluminium Suspension'

# %% [markdown]
# Now, we examine the unique values in the updated '`Front_Suspension`' column of the '`cars`' DataFrame after the standardization process.

# %%
# Display unique values in the updated 'Front_Suspension' column of the 'cars' DataFrame
cars["Front_Suspension"].unique()
# Out:
# array(['Aluminium Suspension', nan, 'Single Joint Suspension',
#        'S sport suspension', 'Sports suspension settings',
#        'Steel Suspension', 'Coil spring with stabilisers', 'Rigid Axle',
#        'Twin wishbones', 'Runflat', 'Hydraulic Telescopic Shock Absorber',
#        'IFS coil spring', 'IFS With Torsion Bar And Stablizer Bar',
#        'Quattroporte Sport GT S is fitted with the single-setting racing-style suspension system',
#        'Push rod magneto-rheologic active',
#        'Aluminium double-joint springs strut axle with anti-roll bar',
#        'Aluminium double track control arm axle with separate lower track arm level, small steering roll radius, traverse force compensation, anti-dive'],
#       dtype=object)

# %% [markdown]
# Here, we inspect the unique values in the '`Rear_Suspension`' column of the '`cars`' DataFrame to understand the different rear suspension configurations recorded in the dataset.

# %%
# Display unique values in the 'Rear_Suspension' column of the 'cars' DataFrame
cars["Rear_Suspension"].unique()
# Out:
# array(['Independent, Semi Trailing arm with coil spring & gas filled shock absorbers',
#        'H-type Torsion Beam', 'Twist beam suspension with coil spring',
#        '3 Link Rigid', '3-link rigid axle Suspension',
#        'Coupled Torsion Beam Axle with coil spring', nan,
#        'Coupled Torsion Beam Axle',
#        'Semi-Independent; Twist beam with dual path strut',
#        'Rear Twist beam with coil spring mounted on hydraulic shock absorbers',
#        'Torsion Beam', 'Torison Beam', '5 rods system',
#        'Twist Beam with Coil spring and Shock Absorber',
#        'Semi-independent trailing arm',
#        'Semi-independent twist beam with twin gas and oil filled shock absorbers',
#        'Semi Independent, Twist Beam with coil Spring and Shock Absorber',
#        'Semi Independent Trailing Arm',
#        'H-Section torsion beam with programmed deflection-coil spring - See more at: http://mahindraverito.com/verito-specs.aspx#sthash.hu39n454.dpuf',
# ...

# %% [markdown]
# This code updates the '`Rear_Suspension`' column in the '`cars`' DataFrame, standardizing various rear suspension types for consistency and clarity.

# %%
# Update 'Rear_Suspension' column in 'cars' DataFrame with standardized suspension types
cars.loc[cars['Rear_Suspension'].str.contains('multi-link|multilink', case=False, na=False), 'Rear_Suspension'] = 'Multi-link Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('torsion beam|torsion bar', case=False, na=False), 'Rear_Suspension'] = 'Torsion Beam Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('double wishbone|wishbone', case=False, na=False), 'Rear_Suspension'] = 'Double Wishbone Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('coil spring|coil-over|coilover', case=False, na=False), 'Rear_Suspension'] = 'Coil Spring Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('independent|macpherson|mcpherson', case=False, na=False), 'Rear_Suspension'] = 'Independent Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('leaf spring|leaf-sprung|leafsprung', case=False, na=False), 'Rear_Suspension'] = 'Leaf Spring Suspension'
cars.loc[cars['Rear_Suspension'].str.contains('Multi-link|Torsion Beam|Double Wishbone|Coil Spring|Independent|Leaf Spring', case=False, na=False), 'Rear_Suspension'] = 'Other Suspension'

# %% [markdown]
# Now, we explore the unique values in the updated '`Rear_Suspension`' column of the '`cars`' DataFrame after the standardization process.

# %%
# Display unique values in the updated 'Rear_Suspension' column of the 'cars' DataFrame
cars['Rear_Suspension'].unique()
# Out:
# array(['Other Suspension', '3 Link Rigid', '3-link rigid axle Suspension',
#        nan, 'Torison Beam', '5 rods system',
#        'Rigid suspension with gas-sealed, twin-tube shock absorber',
#        'Multi link',
#        'multi-element axle, with one longitudinal and transverse links, with torsion stabiliser',
#        'Multi-element axle, with one longitudinal and three transverse links, with torsion stabiliser',
#        'Four Link', '4 link rear axle', 'Four-link',
#        'Four-link rear suspension with separate spring/shock absorber arrangement, subframe, aluminum wheel',
#        'multiple control-arm rear axle', 'Adaptive Dynamics system',
#        'Multi - link',
#        'Five-link front suspension; tubular anti-roll bar',
#        'Dynamic Damper Control', 'Integral link', 'S sport suspension',
#        'Self-levelling with pneumatic rear suspension',
#        'Steel Suspension', 'Adaptive M Suspension',
#        '4-Link with Air Spring',
# ...

# %% [markdown]
# ###11. Processing `Track` Datasets

# %% [markdown]
# Here, we show the first few rows of the '`Front_Track`' and '`Rear_Track`' columns from the '`cars`' DataFrame for inspection.

# %%
 # Display the 'Front_Track' and 'Rear_Track' columns from the 'cars' DataFrame
cars[["Front_Track","Rear_Track"]].head()
# Out:
#   Front_Track Rear_Track
# 0     1325 mm    1315 mm
# 1     1325 mm    1315 mm
# 2     1325 mm    1315 mm
# 3     1325 mm    1315 mm
# 4     1325 mm    1315 mm

# %% [markdown]
# This code cleans and standardizes the '`Front_Track`' and '`Rear_Track`' columns in the '`cars`' DataFrame, renaming columns to reflect units and converting them to float type for consistency.

# %%
# Clean and standardize 'Front_Track' and 'Rear_Track' columns in 'cars' DataFrame
cars['Front_Track'] = cars['Front_Track'].replace(r'\D', '', regex=True)
cars['Rear_Track'] = cars['Rear_Track'].replace(r'\D', '', regex=True)

# Rename columns to reflect units and data type
cars.rename(columns={'Front_Track': 'Front_Track_mm','Rear_Track': 'Rear_Track_mm'}, inplace=True)

# Convert cleaned columns to float type
cars['Front_Track_mm'] = cars['Front_Track_mm'].astype(float)
cars['Rear_Track_mm'] = cars['Rear_Track_mm'].astype(float)

# %% [markdown]
# Here, we show the first few rows of the cleaned and standardized '`Front_Track_mm`' and '`Rear_Track_mm`' columns from the '`cars`' DataFrame for inspection.

# %%
# Display the cleaned and standardized 'Front_Track_mm' and 'Rear_Track_mm' columns from the 'cars' DataFrame
cars[['Front_Track_mm', 'Rear_Track_mm']].head()
# Out:
#    Front_Track_mm  Rear_Track_mm
# 0        1325.000       1315.000
# 1        1325.000       1315.000
# 2        1325.000       1315.000
# 3        1325.000       1315.000
# 4        1325.000       1315.000

# %% [markdown]
# ###12. Processing `Tire` Datasets

# %% [markdown]
# This code removes spaces from the '`Front_Tyre_&_Rim`' column in the '`cars`' DataFrame and displays unique values, ensuring consistent formatting.

# %%
# Remove spaces from the 'Front_Tyre_&_Rim' column in 'cars' DataFrame and display unique values
cars['Front_Tyre_&_Rim'] = cars['Front_Tyre_&_Rim'].str.replace(' ','',regex=False)
cars['Front_Tyre_&_Rim'].unique()
# Out:
# array(['135/70R12', '80/155R13', '155/80R13', '165/70R14', '155R13LT',
#        '155/65R13', '155/70R13', nan, '175/65R14', '175/60R15',
#        '175/65R15', '185/65R14', '185/65R15', '205/70R15', '205/70',
#        '185/60R15', '165/65R14', '165/80R14', '185/70R14', '195/55R16',
#        '175/70R14', '185/60R16', '195/55R15', '175/70R15', '205/55R16',
#        '175/65', '225/60R17', '265/60R17', '245/70R17', '255/60R18',
#        '215/65R17', '235/55R18', '235/65R18', '215/55R17', '205/55R17',
#        '225/45R17', '255/35R20', '215/65R16', '235/55R17', '235/55R19',
#        '225/50R1794Y', '43.66cm/17"LightAlloyWheelsJCWTrackSpoke,Black',
#        '225/55R18', '225/60R19', '245/50R19', '235/60R18', '245/45R18',
#        '245/40R18', '255/50R19', '255/40R19', '265/60R18', '265/50R20',
#        '295/45R20', '255/40R18', '245/35ZR19', '235/40R18', '275/55R19',
#        '295/40R21', '235/60VR18', '265/35R19', '(245/50R18', '245/45R19',
# ...

# %% [markdown]
# This code **splits and extracts** information from the '`Front_Tyre_&_Rim`' column, then **cleans and replaces** specific values in the relevant columns ('`F_Tire_Width`', '`F_Tire_Aspect_Ratio`', '`F_Tire_Diameter`'). The cleaned columns are converted to float type for consistency

# %%
# Split and extract information from 'Front_Tyre_&_Rim' column, and clean relevant columns
cars[['F_Tire_Width', 'F_Tire']] = cars['Front_Tyre_&_Rim'].str.split('/', n=1, expand=True)
cars[['F_Tire_Aspect_Ratio', 'F_Tire_Diameter']] = cars['F_Tire'].str.split('R', n=1, expand=True)

f_drop = ['F_Tire']
cars.drop(columns=f_drop, inplace=True)          # Drop the original 'F_Tire' column

# Clean and replace specific values in the extracted columns
cars['F_Tire_Width'] = cars['F_Tire_Width'].replace({'155R13LT':'155','(245':'245','R12':np.nan,'R16':np.nan,'43.66cm':np.nan,'P215':'215','P235':'235','145R12LT6PR':'145' , '195R15LT,8PRRadial':'195','21565R16':'215'})
cars['F_Tire_Aspect_Ratio'] = cars['F_Tire_Aspect_Ratio'].replace({'17"LightAlloyWheelsJCWTrackSpoke,Black':'43','35Z':'35','Z':'','40/20':'40','30Z':'30','40Z':'40','60/':'60','45Z':'45','60Z':'60','60V':'60','55Z':'55','155':np.nan,None:np.nan})
cars['F_Tire_Diameter'] = cars['F_Tire_Diameter'].replace({'15Steel':'15','18TubelessRadials':'18','F20':'20','1794Y':np.nan,None:np.nan})

# Convert the cleaned columns to float type
cars['F_Tire_Width'] = cars['F_Tire_Width'].astype(float)
cars['F_Tire_Aspect_Ratio'] = cars['F_Tire_Aspect_Ratio'].astype(float)
cars['F_Tire_Diameter'] = cars['F_Tire_Diameter'].astype(float)

# %% [markdown]
# Now, we explore the unique values in the cleaned '`F_Tire_Width`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
# Display unique values in the cleaned 'F_Tire_Width' column of the 'cars' DataFrame
cars['F_Tire_Width'].unique()
# Out:
# array([135.,  80., 155., 165.,  nan, 175., 185., 205., 195., 225., 265.,
#        245., 255., 215., 235., 295., 275., 285., 145., 115.])

# %% [markdown]
# Here, we examine the unique values in the cleaned '`F_Tire_Aspect_Ratio`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
# Display unique values in the cleaned 'F_Tire_Aspect_Ratio' column of the 'cars' DataFrame
cars['F_Tire_Aspect_Ratio'].unique()
# Out:
# array([ 70.,  nan,  80.,  65.,  60.,  55.,  45.,  35.,  50.,  43.,  40.,
#         30.,  75.,  90., 335.,  85.])

# %% [markdown]
# Now, we explore the unique values in the cleaned '`F_Tire_Diameter`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
 # Display unique values in the cleaned 'F_Tire_Diameter' column of the 'cars' DataFrame
cars['F_Tire_Diameter'].unique()
# Out:
# array([12., 13., 14., nan, 15., 16., 17., 18., 20., 19., 21., 22.])

# %% [markdown]
# This code reorders and renames columns in the '`cars`' DataFrame, placing '`F_Tire_Width`', '`F_Tire_Aspect_Ratio`', and '`F_Tire_Diameter`' in front for better organization. The original '`Front_Tyre_&_Rim`' column is dropped.

# %%
# Reorder and rename columns in 'cars' DataFrame for better organization
width = cars.columns.get_loc('F_Tire_Width')
aspect = cars.columns.get_loc('F_Tire_Aspect_Ratio')
diameter = cars.columns.get_loc('F_Tire_Diameter')
front = cars.columns.get_loc('Front_Tyre_&_Rim')

column_to_move = cars.pop('F_Tire_Width')
cars.insert(front, 'F_Tire_Width', column_to_move)         # Move the columns to the desired positions

column_to_move = cars.pop('F_Tire_Aspect_Ratio')
cars.insert(front, 'F_Tire_Aspect_Ratio', column_to_move)

column_to_move = cars.pop('F_Tire_Diameter')
cars.insert(front, 'F_Tire_Diameter', column_to_move)

# Drop the original 'Front_Tyre_&_Rim' column and rename the reordered columns
cars.drop(columns=['Front_Tyre_&_Rim'], inplace=True)
cars.rename(columns={'F_Tire_Width': 'F_Tire_Width_mm', 'F_Tire_Diameter': 'F_Tire_Diameter_inch'}, inplace=True)

# %% [markdown]
# This code removes spaces from the '`Rear_Tyre_&_Rim`' column in the '`cars`' DataFrame and displays unique values, ensuring consistent formatting.

# %%
# Remove spaces from the 'Rear_Tyre_&_Rim' column in 'cars' DataFrame and display unique values
cars['Rear_Tyre_&_Rim'] = cars['Rear_Tyre_&_Rim'].str.replace(' ','', regex=False)
cars['Rear_Tyre_&_Rim'].unique()
# Out:
# array(['155/65R12', '80/155R13', '155/80R13', '165/70R14', '155R13LT',
#        '155/65R13', '155/70R13', nan, '175/65R14', '175/60R15',
#        '175/65R15', '185/65R14', '185/65R15', '205/70R15', '205/70',
#        '185/60R15', '165/65R14', '165/80R14', '185/70R14', '195/55R16',
#        '175/70R14', '185/60R16', '195/55R15', '175/70R15', '205/55R16',
#        '175/65', '225/60R17', '265/60R17', '245/70R17', '255/60R18',
#        '215/65R17', '235/55R18', '235/60R18', '215/55R17', '205/55R17',
#        '225/45R17', '295/30R20', '215/65R16', '235/55R17', '235/55R19',
#        '225/50R1794Y', '43.66cm/17"LightAlloyWheelsJCWTrackSpoke,Black',
#        '225/55R18', '225/60R19', '245/50R19', '245/45R18', '245/40R18',
#        '255/50R19', '275/40R19', '265/60R18', '265/50R20', '295/45R20',
#        '255/35R18', '265/35ZR19', '235/40R18', '275/55R19', '295/40R21',
#        '235/60VR18', '265/35R19', '(245/50R18', '275/35R20', '275/50R20',
# ...

# %% [markdown]
# This code **splits and extracts** information from the '`Rear_Tyre_&_Rim`' column, then **cleans and replaces** specific values in the relevant columns ('`R_Tire_Width`', '`R_Tire_Aspect_Ratio`', '`R_Tire_Diameter`'). The cleaned columns are converted to float type for consistency.

# %%
# Split and extract information from 'Rear_Tyre_&_Rim' column, and clean relevant columns
cars[['R_Tire_Width', 'R_Tire']] = cars['Rear_Tyre_&_Rim'].str.split('/', n=1, expand=True)
cars[['R_Tire_Aspect_Ratio', 'R_Tire_Diameter']] = cars['R_Tire'].str.split('R', n=1, expand=True)

r_drop = ['R_Tire']
cars.drop(columns=r_drop, inplace=True)                # Drop the original 'R_Tire' column

# Clean and replace specific values in the extracted columns
cars['R_Tire_Width'] = cars['R_Tire_Width'].replace({'155R13LT':'155','(245':'245','R12':np.nan,'R16':np.nan,'43.66cm':np.nan,'P215':'215','P235':'235','145R12LT6PR':'145' , '195R15LT,8PRRadial':'195','21565R16':'215'})
cars['R_Tire_Aspect_Ratio'] = cars['R_Tire_Aspect_Ratio'].replace({'17"LightAlloyWheelsJCWTrackSpoke,Black':'43','35/20':'35','25Z':'25','50Z':'50','335':np.nan,'60/':'60','30Z':'30','60Z':'60','40Z':'40','60V':'60','35Z':'35','155':np.nan,None:np.nan})
cars['R_Tire_Diameter'] = cars['R_Tire_Diameter'].replace({None:np.nan,'1794Y':np.nan,'15Steel':'15','18TubelessRadials':'18','F20':'20'})

# Convert the cleaned columns to float type
cars['R_Tire_Width'] = cars['R_Tire_Width'].astype(float)
cars['R_Tire_Aspect_Ratio'] = cars['R_Tire_Aspect_Ratio'].astype(float)
cars['R_Tire_Diameter'] = cars['R_Tire_Diameter'].astype(float)

# %% [markdown]
# Now, we explore the unique values in the cleaned '`R_Tire_Width`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
 # Display unique values in the cleaned 'R_Tire_Width' column of the 'cars' DataFrame
cars['R_Tire_Width'].unique()
# Out:
# array([155.,  80., 165.,  nan, 175., 185., 205., 195., 225., 265., 245.,
#        255., 215., 235., 295., 275., 285., 315., 305., 145., 115., 325.,
#        335., 355.])

# %% [markdown]
# Here, we examine the unique values in the cleaned '`R_Tire_Aspect_Ratio`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
 # Display unique values in the cleaned 'R_Tire_Aspect_Ratio' column of the 'cars' DataFrame
cars['R_Tire_Aspect_Ratio'].unique()
# Out:
# array([65., nan, 80., 70., 60., 55., 45., 30., 50., 43., 40., 35., 75.,
#        90., 85., 25.])

# %% [markdown]
# Now, we explore the unique values in the cleaned '`R_Tire_Diameter`' column of the '`cars`' DataFrame after the data cleaning and standardization process.

# %%
 # Display unique values in the cleaned 'R_Tire_Diameter' column of the 'cars' DataFrame
cars['R_Tire_Diameter'].unique()
# Out:
# array([12., 13., 14., nan, 15., 16., 17., 18., 20., 19., 21., 22.])

# %% [markdown]
# This code reorders and renames columns in the '`cars`' DataFrame, placing '`R_Tire_Width`', '`R_Tire_Aspect_Ratio`', and '`R_Tire_Diameter`' in front for better organization. The original '`Rear_Tyre_&_Rim`' column is dropped.

# %%
# Reorder and rename columns in 'cars' DataFrame for better organization
width = cars.columns.get_loc('R_Tire_Width')
aspect = cars.columns.get_loc('R_Tire_Aspect_Ratio')
diameter = cars.columns.get_loc('R_Tire_Diameter')
rear = cars.columns.get_loc('Rear_Tyre_&_Rim')

# Move the columns to the desired positions
column_to_move = cars.pop('R_Tire_Width')
cars.insert(rear, 'R_Tire_Width', column_to_move)

column_to_move = cars.pop('R_Tire_Aspect_Ratio')
cars.insert(rear, 'R_Tire_Aspect_Ratio', column_to_move)

column_to_move = cars.pop('R_Tire_Diameter')
cars.insert(rear, 'R_Tire_Diameter', column_to_move)

# Drop the original 'Rear_Tyre_&_Rim' column and rename the reordered columns
cars.drop(columns=['Rear_Tyre_&_Rim'], inplace=True)
cars.rename(columns={'R_Tire_Width': 'R_Tire_Width_mm', 'R_Tire_Diameter': 'R_Tire_Diameter_inch'}, inplace=True)

# %% [markdown]
# ###13. Processing `Power` and `Torque` Datasets

# %%
cars['Power'].unique()
# Out:
# array(['38PS@5500rpm', '54PS@5678rpm', '68PS@5500rpm', '73PS@6000rpm',
#        '74PS@6000RPM', '62PS@6000rpm', '68PS@6000rpm', '68PS@6200rpm',
#        '59PS@6000rpm', '68PS@5000rpm', '78PS@5000rpm', '59bhp@6000rpm',
#        '69PS@5500rpm', '59PS@5500RPM', '86PS@6000rpm', '83PS@6000rpm',
#        '72PS@62050rpm', '76.6PS@5800rpm', '64PS@4000rpm', '72PS@4000rpm',
#        '80PS@5600rpm', '68PS@3800rpm', '75PS@4000rpm', '90PS@5000rpm',
#        '81.8bhp@6000rpm', '70bhp@4000RPM', '71PS@4000rpm',
#        '69bhp@6000rpm', '84PS@6000rpm', '90PS@4000rpm', '69PS@6000rpm',
#        '100PS@6000rpm', '76PS@6200RPM', '90PS@4200rpm', '105PS@5000rpm',
#        '110PS@4400rpm', '84.3PS@6000rpm', '100PS@3750RPM', '96PS@6500rpm',
#        '100PS@3700RPM', '96PS@6300rpm', '90PS@5600rpm', '65PS@4000rpm',
#        '93PS@4000RPM', '140ps@5500rpm', '89PS@6000 rpm', '82PS@6000 rpm',
#        '90PS@6000rpm', '100PS@3600rpm', '89 bhp@6000rpm', '173PS@3750rpm',
# ...

# %% [markdown]
# This code splits and extracts information from the '`Power`' column into '`Power_PS`' (power in PS) and '`Power_RPM`' (power at RPM) columns, displaying the first five rows for reference.

# %%
# Split and extract information from 'Power' column into 'Power_PS' and 'Power_RPM' columns
cars[['Power_PS', 'Power_RPM']] = cars['Power'].str.split('@', n=1, expand=True)
cars[['Power_PS', 'Power_RPM']].head()
# Out:
#   Power_PS Power_RPM
# 0     38PS   5500rpm
# 1     38PS   5500rpm
# 2     38PS   5500rpm
# 3     38PS   5500rpm
# 4     38PS   5500rpm

# %% [markdown]
# In this code, we clean the '`Power_PS`' column by removing non-numeric characters and converting it to **float** type. The unique values in the cleaned column are then displayed.

# %%
# Clean and convert 'Power_PS' column to float type
cars['Power_PS'] = cars['Power_PS'].replace(r'[A-Za-z]', '', regex=True)
cars['Power_PS'] = cars['Power_PS'].astype(float)

# Display unique values in the cleaned 'Power_PS' column of the 'cars' DataFrame
cars['Power_PS'].unique()
# Out:
# array([  38.  ,   54.  ,   68.  ,   73.  ,   74.  ,   62.  ,   59.  ,
#          78.  ,   69.  ,   86.  ,   83.  ,   72.  ,   76.6 ,   64.  ,
#          80.  ,   75.  ,   90.  ,   81.8 ,   70.  ,   71.  ,   84.  ,
#         100.  ,   76.  ,  105.  ,  110.  ,   84.3 ,   96.  ,   65.  ,
#          93.  ,  140.  ,   89.  ,   82.  ,  173.  ,  177.  ,  178.  ,
#         141.  ,  154.  ,  120.  ,  180.  ,  143.  ,  150.  ,  122.  ,
#         136.  ,  183.  ,  148.  ,  250.  ,  116.  ,  192.  ,  190.  ,
#         231.  ,  247.  ,  245.  ,  248.  ,  179.  ,  333.  ,  265.  ,
#         340.  ,  401.  ,  240.  ,  468.  ,  286.  ,  334.  ,  410.  ,
#         300.  ,  258.  ,  557.  ,  262.  ,  450.  ,  609.  ,  275.  ,
#         350.  ,  430.  ,  585.  ,  289.  ,  460.  ,  299.  ,  630.  ,
#         453.  ,  550.  ,  261.  ,  455.  ,  610.  ,  650.  ,  590.  ,
#         560.  ,  608.  ,  605.  ,  563.  ,  570.  ,  625.  ,  512.  ,
# ...

# %% [markdown]
# In this code, the '`Power_RPM`' column is cleaned by removing non-numeric characters. Additionally, specific values are replaced, and the column is converted to float type. The unique values in the cleaned '`Power_RPM`' column are then displayed.

# %%
# Clean and convert 'Power_RPM' column to float type
cars['Power_RPM'] = cars['Power_RPM'].replace(r'[A-Za-z]', '', regex=True)

# Replace specific values and convert to float type
cars.loc[cars['Power_RPM'].str.contains('-4', case=False, na=False), 'Power_RPM'] = '4000'
cars.loc[cars['Power_RPM'].str.contains('-6', case=False, na=False), 'Power_RPM'] = '6000'
cars.loc[cars['Power_RPM'].str.contains('-7', case=False, na=False), 'Power_RPM'] = '7000'

# Display unique values in the cleaned 'Power_RPM' column of the 'cars' DataFrame
cars['Power_RPM'] = cars['Power_RPM'].astype(float)
cars['Power_RPM'].unique()
# Out:
# array([ 5500.,  5678.,  6000.,  6200.,  5000., 62050.,  5800.,  4000.,
#         5600.,  3800.,  4200.,  4400.,  3750.,  6500.,  3700.,  6300.,
#         3600.,   400.,    nan,  5100.,  5200.,  4250.,  6550.,  6250.,
#         6350.,  7000.,  5250.,  3400.,  5750.,  1200.,  6600.,  4800.,
#         8250.,  7500.,  9000.,  5350.,  6700.,  3200.,  6400.,  3500.,
#         4500.,   150.,  3000.,  5700.,   500.,  5300.,  8000.,  8400.,
#         3850.,  3900.,  5850.,  7300.,  6800.,  6650.,  8500.,  5400.,
#         6100.])

# %% [markdown]
# This code reorders and renames columns in the '`cars`' DataFrame, placing '`Power_PS`' and '`Power_RPM`' in front for better organization. The original '`Power`' column is dropped.

# %%
# Reorder and rename columns in 'cars' DataFrame for better organization
index_of_Power_RPM = cars.columns.get_loc('Power_RPM')
index_of_Power_PS = cars.columns.get_loc('Power_PS')
index_of_Power = cars.columns.get_loc('Power')

# Move the columns to the desired positions
column_to_move = cars.pop('Power_PS')
cars.insert(index_of_Power, 'Power_PS', column_to_move)

column_to_move = cars.pop('Power_RPM')
cars.insert(index_of_Power, 'Power_RPM', column_to_move)

# Drop the original 'Power' column
cars.drop(columns=['Power'], inplace=True)

# Display the first five rows of 'Power_PS' and 'Power_RPM' columns in 'car' DataFrame
cars[['Power_PS', 'Power_RPM']].head()
# Out:
#    Power_PS  Power_RPM
# 0    38.000   5500.000
# 1    38.000   5500.000
# 2    38.000   5500.000
# 3    38.000   5500.000
# 4    38.000   5500.000

# %% [markdown]
# Here, we show the first five rows of the '`Torque`' column in the '`cars`' DataFrame to provide a glimpse of the data.

# %%
cars['Torque'].head()
# Out:
# 0    51Nm@4000rpm
# 1    51Nm@4000rpm
# 2    51Nm@4000rpm
# 3    51Nm@4000rpm
# 4    51Nm@4000rpm
# Name: Torque, dtype: object

# %% [markdown]
# This code splits and extracts information from the '`Torque`' column into '`Torque_Nm`' (torque in Nm) and '`Torque_RPM`' (torque at RPM) columns, displaying the first five rows for reference.

# %%
# Split and extract information from 'Torque' column into 'Torque_Nm' and 'Torque_RPM' columns
cars[['Torque_Nm', 'Torque_RPM']] = cars['Torque'].str.split('@', n=1, expand=True)
cars[['Torque_Nm', 'Torque_RPM']].head()
# Out:
#   Torque_Nm Torque_RPM
# 0      51Nm    4000rpm
# 1      51Nm    4000rpm
# 2      51Nm    4000rpm
# 3      51Nm    4000rpm
# 4      51Nm    4000rpm

# %% [markdown]
# In this code, the '`Torque_Nm`' column is cleaned by removing non-numeric characters and then converted to float type. The unique values in the cleaned '`Torque_Nm`' column are displayed.

# %%
# Clean and convert 'Torque_Nm' column to float type
cars['Torque_Nm'] = cars['Torque_Nm'].replace(r'[A-Za-z]', '', regex=True)
cars['Torque_Nm'] = cars['Torque_Nm'].astype(float)

# Display unique values in the cleaned 'Torque_Nm' column of the 'cars' DataFrame
cars['Torque_Nm'].unique()
# Out:
# array([  51.  ,   72.  ,   91.  ,  101.  ,   85.  ,   90.  ,   78.  ,
#         104.  ,   99.04,   10.1 ,    8.3 ,  114.  ,  113.  ,   96.  ,
#         103.9 ,  152.  ,  183.  ,  170.  ,  190.  ,  140.  ,  115.  ,
#         220.  ,   95.  ,  172.  ,  230.  ,  175.  ,  250.  ,  215.  ,
#         120.  ,  132.  ,  160.  ,  209.  ,  210.  ,  110.  ,  200.  ,
#         350.  ,  380.  ,  420.  ,  340.  ,  189.  ,  300.  ,  320.  ,
#         270.  ,  280.  ,  400.  ,  365.  ,  430.  ,  370.  ,  500.  ,
#         620.  ,  450.  ,  515.  ,  570.  ,  624.  ,  347.  ,  480.  ,
#         550.  ,  619.  ,  760.  ,  410.  ,  335.  ,  600.  ,  850.  ,
#         900.  ,  580.  ,  520.  , 1000.  ,  700.  ,  770.  ,  650.  ,
#         560.  ,  720.  ,  755.  ,  540.  ,  780.  ,  800.  , 1020.  ,
#        1600.  , 1479.  ,   18.9 ,   16.1 ,   69.  ,   16.3 ,  240.  ,
#         103.  ,  112.7 , 1712.  ,   22.4 ,  260.  ,  207.  ,  195.  ,
# ...

# %% [markdown]
# This code snippet cleans the '`Torque_RPM`' column by removing non-numeric characters, replaces specific values, and converts the column to float type. The unique values in the cleaned '`Torque_RPM`' column are then displayed.

# %%
# Clean and convert 'Torque_RPM' column to float type
cars['Torque_RPM'] = cars['Torque_RPM'].replace(r'[A-Za-z]', '', regex=True)

# Replace specific values and convert to float type
cars.loc[cars['Torque_RPM'].str.contains('-1', case=False, na=False), 'Torque_RPM'] = '1000'
cars.loc[cars['Torque_RPM'].str.contains('-2', case=False, na=False), 'Torque_RPM'] = '2000'
cars.loc[cars['Torque_RPM'].str.contains('-3|- 3', case=False, na=False), 'Torque_RPM'] = '3000'
cars.loc[cars['Torque_RPM'].str.contains('-4|- 4', case=False, na=False), 'Torque_RPM'] = '4000'
cars.loc[cars['Torque_RPM'].str.contains('-5|- 5', case=False, na=False), 'Torque_RPM'] = '5000'
cars.loc[cars['Torque_RPM'].str.contains('-6', case=False, na=False), 'Torque_RPM'] = '6000'

cars['Torque_RPM'] = cars['Torque_RPM'].astype(float)

# Display unique values in the cleaned 'Torque_RPM' column of the 'car' DataFrame
cars['Torque_RPM'].unique()
# Out:
# array([4000., 4386., 4250., 3000., 3500., 4500., 3300., 4200., 2500.,
#        2250., 2000., 3100., 6000., 1500., 4400., 4800., 1750., 4300.,
#        5000.,   nan, 1250., 1450., 4100., 5250., 4600., 1370., 4750.,
#        5100., 6500., 1800., 1350., 1700., 1600., 6700., 2200., 4850.,
#        1900., 3800., 1000., 1550., 2400., 1740., 5300., 5500., 5506.,
#        3750., 3600., 3200., 7000., 1360.])

# %% [markdown]
# This code reorders and renames columns in the '`cars`' DataFrame, placing '`Torque_Nm`' and '`Torque_RPM`' in front for better organization. The original '`Torque`' column is dropped.

# %%
# Reorder and rename columns in 'cars' DataFrame for better organization
index_of_Torque_RPM = cars.columns.get_loc('Torque_RPM')
index_of_Torque_Nm = cars.columns.get_loc('Torque_Nm')
index_of_Torque = cars.columns.get_loc('Torque')

# Move the columns to the desired positions
column_to_move = cars.pop('Torque_Nm')
cars.insert(index_of_Torque, 'Torque_Nm', column_to_move)

column_to_move = cars.pop('Torque_RPM')
cars.insert(index_of_Torque, 'Torque_RPM', column_to_move)

# Drop the original 'Torque' column
cars.drop(columns=['Torque'], inplace=True)

# Display the first five rows of 'Torque_Nm' and 'Torque_RPM' columns in 'car' DataFrame
cars[['Torque_Nm', 'Torque_RPM']].head()
# Out:
#    Torque_Nm  Torque_RPM
# 0     51.000    4000.000
# 1     51.000    4000.000
# 2     51.000    4000.000
# 3     51.000    4000.000
# 4     51.000    4000.000

# %% [markdown]
# ###14. Processing `Power_Steering`, `Power_Windows`, `Power_Seats` and `Keyless_Entry` Datasets

# %% [markdown]
# This code snippet displays the unique values in the '`Power_Steering`' column of the '`cars`' DataFrame.

# %%
 # Display unique values in the 'Power_Steering' column of the 'cars' DataFrame
cars['Power_Steering'].unique()
# Out:
# array(['Electric Power', nan, 'Yes', 'Hydraulic Power',
#        'Electric Power, Hydraulic Power', 'Electro-Hydraulic'],
#       dtype=object)

# %% [markdown]
# In this code, values in the '`Power_Steering`' column are replaced for better categorization. The modified unique values in the '`Power_Steering`' column are then displayed.

# %%
# Replace values in the 'Power_Steering' column for better categorization
cars['Power_Steering'] = cars['Power_Steering'].replace({'Electric Power, Hydraulic Power':'Electro-Hydraulic','Yes':'Undefined Powered',np.nan:'Non Powered'})

# Display unique values in the modified 'Power_Steering' column of the 'cars' DataFrame
cars['Power_Steering'].unique()
# Out:
# array(['Electric Power', 'Non Powered', 'Undefined Powered',
#        'Hydraulic Power', 'Electro-Hydraulic'], dtype=object)

# %% [markdown]
# This code snippet displays the unique values in the '`Power_Windows`' column of the '`cars`' DataFrame.

# %%
# Display unique values in the 'Power_Windows' column of the 'cars' DataFrame
cars['Power_Windows'].unique()
# Out:
# array(['Only Front Windows', nan, 'All Windows'], dtype=object)

# %% [markdown]
# In this code, values in the '`Power_Windows`' column are replaced for better categorization. The modified unique values in the '`Power_Windows`' column are then displayed.

# %%
# Replace values in the 'Power_Windows' column for better categorization
cars['Power_Windows'] = cars['Power_Windows'].replace({'Only Front Windows':'Front Windows',np.nan:'Non Powered'})

# Display unique values in the modified 'Power_Windows' column of the 'cars' DataFrame
cars['Power_Windows'].unique()
# Out:
# array(['Front Windows', 'Non Powered', 'All Windows'], dtype=object)

# %% [markdown]
# This code snippet displays the unique values in the '`Power_Seats`' column of the '`cars`' DataFrame.

# %%
  # Display unique values in the 'Power_Seats' column of the 'cars' DataFrame
cars['Power_Seats'].unique()
# Out:
# array([nan, 'Yes', 'Power seats', 'Yes, with memory'], dtype=object)

# %% [markdown]
# In this code, values in the '`Power_Seats`' column are modified for better categorization. The modified unique values in the '`Power_Seats`' column are then displayed

# %%
# Modify values in the 'Power_Seats' column for better categorization
cars.loc[cars['Power_Seats'].str.contains('Yes|Power', case=False, na=False), 'Power_Seats'] = 'Powered Seats'
cars['Power_Seats'] = cars['Power_Seats'].replace(np.nan,'Non Powered')

# Display unique values in the modified 'Power_Seats' column of the 'cars' DataFrame
cars['Power_Seats'].unique()
# Out:
# array(['Non Powered', 'Powered Seats'], dtype=object)

# %% [markdown]
# This code snippet displays the unique values in the '`Keyless_Entry`' column of the '`cars`' DataFrame.

# %%
# Display unique values in the 'Keyless_Entry' column of the 'cars' DataFrame
cars['Keyless_Entry'].unique()
# Out:
# array(['Remote', nan, 'Yes', 'Smart Key', 'Remote, Smart Key',
#        'Smart Key, Remote'], dtype=object)

# %% [markdown]
# Now the, values in the '`Keyless_Entry`' column are modified for better categorization. The modified unique values in the '`Keyless_Entry`' column are then displayed.

# %%
# Modify values in the 'Keyless_Entry' column for better categorization
cars.loc[cars['Keyless_Entry'].str.contains('Yes|Key|Remote', case=False, na=False), 'Keyless_Entry'] = 'Yes'
cars['Keyless_Entry'] = cars['Keyless_Entry'].replace(np.nan,'No')

# Display unique values in the modified 'Keyless_Entry' column of the 'car' DataFrame
cars['Keyless_Entry'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ###15. Processing Other Features - Datasets

# %% [markdown]
# Now, we are displaying the unique values in the '`Odometer`' column of the '`cars`' DataFrame.

# %%
cars['Odometer'].unique()
# Out:
# array(['Digital', 'Analog', nan, 'Digital, Analog', 'Yes'], dtype=object)

# %% [markdown]
# Now, we are modifying values in the '`Odometer`' column for better categorization, and displaying the unique values in the modified '`Odometer`' column of the '`cars`' DataFrame.

# %%
# Modify values in the 'Odometer' column for better categorization
cars['Odometer'] = cars['Odometer'].replace({'Digital, Analog':'Digi-Analog','Yes':'Unspecified'})

# Display unique values in the modified 'Odometer' column of the 'cars' DataFrame
cars['Odometer'].unique()
# Out:
# array(['Digital', 'Analog', nan, 'Digi-Analog', 'Unspecified'],
#       dtype=object)

# %% [markdown]
# Now, we are displaying the unique values in the '`Speedometer`' column of the '`cars`' DataFrame.

# %%
cars['Speedometer'].unique()
# Out:
# array(['Analog', 'Digital', 'Analog, Digital', 'Digital, Analog', nan,
#        'Yes'], dtype=object)

# %% [markdown]
# Now, we are modifying values in the '`Speedometer`' column for better categorization and displaying the unique values in the modified '`Speedometer`' column of the '`cars`' DataFrame.

# %%
# Modify values in the 'Speedometer' column for better categorization
cars['Speedometer'] = cars['Speedometer'].replace({'Analog, Digital':'Digi-Analog','Digital, Analog':'Digi-Analog','Yes':'Unspecified'})

# Display unique values in the modified 'Speedometer' column of the 'cars' DataFrame
cars['Speedometer'].unique()
# Out:
# array(['Analog', 'Digital', 'Digi-Analog', nan, 'Unspecified'],
#       dtype=object)

# %% [markdown]
# Now, we are displaying the unique values in the '`Tachometer`' column of the '`cars`' DataFrame.

# %%
cars['Tachometer'].unique()
# Out:
# array(['Not on offer', 'Digital', 'Analog', 'Analog, Digital',
#        'Digital, Analog', 'Yes', nan, 'Analog, Not on offer'],
#       dtype=object)

# %% [markdown]
# Now, we are updating values in the '`Tachometer`' column for better categorization and displaying the unique values in the modified '`Tachometer`' column of the '`cars`' DataFrame.

# %%
# Update values in the 'Tachometer' column for better categorization
cars.loc[cars['Tachometer'].str.contains('Yes|Analog|Digital', case=False, na=False), 'Tachometer'] = 'Yes'
cars.loc[cars['Tachometer'].str.contains('Not', case=False, na=False), 'Tachometer'] = 'No'
cars['Tachometer'] = cars['Tachometer'].replace(np.nan,'No')

# Display unique values in the modified 'Tachometer' column of the 'cars' DataFrame
cars['Tachometer'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Now, we are displaying the value counts for the '`Tripmeter`' column in the '`cars`' DataFrame.

# %%
# Display value counts for the 'Tripmeter' column in the 'cars' DataFrame
cars['Tripmeter'].value_counts()
# Out:
# Tripmeter
# Yes     986
# 2       197
# 1        26
# 1, 2      7
# Name: count, dtype: int64

# %% [markdown]
# Now, we have updated the '`Tripmeter`' column by setting non-null values to '`Yes`' and replacing remaining `NaN` values with '`No`'. The updated value counts are displayed.

# %%
# Update 'Tripmeter' column: If not null, set to 'Yes'; otherwise, set to 'No'
cars['Tripmeter'] = np.where(cars['Tripmeter'].notnull(), 'Yes', cars['Tripmeter'])

# Replace remaining NaN values with 'No' in the 'Tripmeter' column
cars['Tripmeter'] = cars['Tripmeter'].replace(np.nan, 'No')

# Display updated value counts for the 'Tripmeter' column in the 'cars' DataFrame
cars['Tripmeter'].value_counts()
# Out:
# Tripmeter
# Yes    1216
# No       60
# Name: count, dtype: int64

# %% [markdown]
# Now, we are randomly sampling 5 entries from the '`Wheelbase`' column in the '`cars`' DataFrame to get an overview of its values.

# %%
cars['Wheelbase'].sample(5)
# Out:
# 974    2610 mm
# 77     2636 mm
# 65     2425 mm
# 905    2520 mm
# 527    2603 mm
# Name: Wheelbase, dtype: object

# %% [markdown]
# Now, we have cleaned and converted the '`Wheelbase`' column to numerical values in millimeters, renaming it as '`Wheelbase_mm`' in the process.

# %%
# Clean and convert the 'Wheelbase' column to numerical values in millimeters
cars['Wheelbase'] = cars['Wheelbase'].replace(r'\D', '', regex=True)
cars.rename(columns={'Wheelbase': 'Wheelbase_mm'}, inplace=True)
cars['Wheelbase_mm'] = cars['Wheelbase_mm'].astype(float)

# %% [markdown]
# Now, we can see the unique values in the cleaned '`Wheelbase_mm`' column of the '`cars`' DataFrame.

# %%
cars['Wheelbase_mm'].unique()
# Out:
# array([2230., 2348., 2422., 2442., 2350., 2360., 2450., 2425., 2400.,
#        2435., 2636., 2420., 2460., 2470., 2430., 2525., 2570., 2469.,
#        2490., 2550., 2630., 2510., 2520., 2530., 2845., 2865., 2677.,
#        2660., 2841., 2637., 2699., 2700., 2603.,   nan, 2702., 2670.,
#        2820., 2495., 2835., 2960., 3157., 2595., 2912., 2810., 2741.,
#        2941., 2811., 2575., 2720., 2915., 2760., 2693., 2475., 3075.,
#        2790., 3210., 3110., 2994., 3035., 3165., 2945., 3004., 2850.,
#        2890., 3128., 2942., 3171., 2870., 3365., 2950., 3100., 2650.,
#        3003., 2746., 2669., 2992., 2995., 2600., 3295., 3112., 3266.,
#        3320., 2710., 1925., 2380., 2385., 2501., 2541., 2375., 2500.,
#        2498., 2680., 2794., 2519., 2579., 2673., 2553., 2258., 2662.,
#        2750., 2740., 3040., 2552., 2585., 3060., 2647., 2745., 2791.,
#        2776., 2774., 2807., 2681., 3079., 2874., 2864., 3008., 2840.,
# ...

# %% [markdown]
# Now, we have removed the '`Wheels_Size`' column from the '`cars`' DataFrame ad we have earlier determined the wheelbase and tire size

# %%
# Remove the 'Wheels_Size' column from the 'cars' DataFrame
cars.drop(columns='Wheels_Size', inplace=True)

# %% [markdown]
# Now, we can see the unique values in the cleaned '`Basic_Warranty`' column of the '`cars`' DataFrame.

# %%
cars['Basic_Warranty'].unique()
# Out:
# array(['2 years /75000 Kms (years/distance whichever comes first)',
#        '2 years / Unlimited Kms',
#        '2 Years / 50,000 Kms (Whichever comes earlier)', nan,
#        '2 years /40000 Kms (years/distance whichever comes first)',
#        '2 Years / 75,000 KM (whichever is earlier)',
#        '3 years /100000 Kms (years/distance whichever comes first)',
#        '24 months /50000 Kms (whichever comes first)',
#        '2 Years / 100,000 Kms (whichever comes first)',
#        '3 Years/1,00,000 Kms (Whichever comes earlier)',
#        '2 Years / 40,000 Kms (Whichever comes earlier)',
#        '3 years / Unlimited Kms',
#        '3 Years / 100000 km (whichever comes first)',
#        '2 Years Unlimited Kilometres',
#        '3rd years /Unlimited Kms (years/distance whichever comes first)',
#        '3 years/40,000 km', '2 Years Warranty',
#        '4 years / 80000 Kms (years/distance whichever comes first)',
# ...

# %% [markdown]
# This code snippet updates the '`Basic_Warranty`' column in the '`cars`' DataFrame based on specified conditions, renames it to '`Basic_Warranty_years`', and converts the values to float.

# %%
# Update the 'Basic_Warranty' column in the 'cars' DataFrame based on the specified conditions
cars.loc[cars['Basic_Warranty'].str.contains('1 Year', na=False), 'Basic_Warranty'] = '1'
cars.loc[cars['Basic_Warranty'].str.contains('2 years|2 Years|24 months', na=False), 'Basic_Warranty'] = '2'
cars.loc[cars['Basic_Warranty'].str.contains('3 years|3 Years|3rd years', na=False), 'Basic_Warranty'] = '3'
cars.loc[cars['Basic_Warranty'].str.contains('4 years', na=False), 'Basic_Warranty'] = '4'
cars.loc[cars['Basic_Warranty'].str.contains('8 yrs', na=False), 'Basic_Warranty'] = '8'

# Rename the 'Basic_Warranty' column to 'Basic_Warranty_years' and convert to float
cars.rename(columns={'Basic_Warranty': 'Basic_Warranty_years'}, inplace=True)
cars['Basic_Warranty_years'] = cars['Basic_Warranty_years'].astype(float)

# %% [markdown]
# This code snippet will show the value counts for the '`Basic_Warranty_years`' column in the '`cars`' DataFrame, indicating how many occurrences there are for each unique value in that column.

# %%
cars['Basic_Warranty_years'].value_counts()
# Out:
# Basic_Warranty_years
# 2.000    486
# 3.000    332
# 4.000     12
# 1.000      3
# 8.000      3
# Name: count, dtype: int64

# %% [markdown]
# This code snippet will show the unique values present in the '`Boot_Space`' column of the '`cars`' DataFrame.

# %%
cars['Boot_Space'].unique()
# Out:
# array(['110 litres', '94 litres', '222 litres', '300 litres',
#        '400 litres', '250 litres', '177 litres', '265 litres',
#        '235 litres', nan, '242 litres', '240 litres', '260 litres',
#        '625 litres', '454 litres', '251 litres', '210 litres',
#        '407 litres', '320 litres', '316 litres', '285 litres',
#        '280 litres', '378 litres', '257 litres', '330 litres',
#        '592 litres', '339 litres', '354 litres', '438 litres',
#        '615 litres', '522 litres', '150 litres', '425 litres',
#        '488 litres', '470 litres', '460 litres', '278 litres',
#        '215 litres', '432 litres', '360 litres', '480 litres',
#        '455 litres', '505 litres', '520 litres', '560 litres',
#        '550 litres', '650 litres', '1025 litres', '540 litres',
#        '465 litres', '515 litres', '500 litres', '605 litres',
#        '530 litres', '510 litres', '580 litres', '261 litres',
#        '133 litres', '616 litres', '358 litres', '430 litres',
# ...

# %% [markdown]
# This code snippet cleans and converts the '`Boot_Space`' column in the '`cars`' DataFrame to a float type, handling a specific case in the data

# %%
# Clean and convert 'Boot_Space' column to float type
cars['Boot_Space'] = cars['Boot_Space'].replace('209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres',np.nan)
cars['Boot_Space'] = cars['Boot_Space'].replace(r'\D', '', regex=True)
cars.rename(columns={'Boot_Space': 'Boot_Space_litres'}, inplace=True)
cars['Boot_Space_litres'] = cars['Boot_Space_litres'].astype(float)

# %% [markdown]
# Now, we can use this code snippet to display the unique values in the '`Boot_Space_litres`' column of the '`cars`' DataFrame.

# %%
cars['Boot_Space_litres'].unique()
# Out:
# array([ 110.,   94.,  222.,  300.,  400.,  250.,  177.,  265.,  235.,
#          nan,  242.,  240.,  260.,  625.,  454.,  251.,  210.,  407.,
#         320.,  316.,  285.,  280.,  378.,  257.,  330.,  592.,  339.,
#         354.,  438.,  615.,  522.,  150.,  425.,  488.,  470.,  460.,
#         278.,  215.,  432.,  360.,  480.,  455.,  505.,  520.,  560.,
#         550.,  650., 1025.,  540.,  465.,  515.,  500.,  605.,  530.,
#         510.,  580.,  261.,  133.,  616.,  358.,  430.,  230.,  490.,
#         443.,  395.,   20.,  256.,  243.,  268.,  345.,  419.,  390.,
#         420.,  350., 1702.,  328.,  352.,  475.,  259.,  207.,  759.,
#         494.,  135.,  255.,  223.,  600.,  209.,  384.,   96.,  128.,
#         448.,  324.,  296.,  211.,  270.,  380.,  495., 1400.,  281.,
#         295.,  909., 1761.,  478.,  645.,  745.,  770.,  621.,  535.,
#         173.,  165.,   70.,  450.,  525.,  347.,  363.,  375.,  392.,
# ...

# %% [markdown]
# Now we have dropped the 'Extended_Warranty' column from the 'cars' DataFrame as we no further require the warranty.

# %%
cars.drop(columns='Extended_Warranty', inplace=True)

# %% [markdown]
# Now we will process the '`Minimum_Turning_Radius`' column in the '`cars`' DataFrame.

# %%
cars['Minimum_Turning_Radius'].unique()
# Out:
# array(['4 meter', '4.7 meter', nan, '4.5 meter', '4.6 meter', '4.9 meter',
#        '4.8 meter', '4.65 meter', '5.1 meter', '5.2 meter', '4.97 meter',
#        '5 meter', '5.25 meter', '6.2 meter', '5.5 meter', '5.75 meter',
#        '5.4 meter', '11.1 meter', '11 meter', '6 meter', '5.9 meter',
#        '5.7 meter', '11.22 meter', '11.61 meter', '5.95 meter',
#        '11.6 meter', '5.8 meter', '5.6 meter', '7.5 meter', '6.15 meter',
#        '6.45 meter', '13.5 meter', '6.35 meter', '10.7 meter',
#        '11.8 meter', '5.3 meter', '6.9 meter', '3.5 meter', '5.05 meter',
#        '5.55 meter', '4.35 meter', '6.25 meter', '5.65 meter',
#        '5.35 meter', '11.7 meter', '10.8 meter', '6.1 meter', '6.3 meter',
#        '12.1 meter', '5.85 meter', '11.9 meter', '6.55 meter',
#        '4.1 meter', '5.45 meter', '5.61 meter', '5.64 meter',
#        '11.87 meter', '11.84 meter', '11.4 meter', '10.66 meter',
#        '5.33 meter', '6750 meter'], dtype=object)

# %% [markdown]
# In this step, non-digit characters are removed from the '`Minimum_Turning_Radius`' column, the column is renamed to '`Minimum_Turning_Radius_meter`' for clarity, and the values are converted to float in the '`cars`' DataFrame.

# %%
# Removing non-digit characters from the 'Minimum_Turning_Radius' column
cars['Minimum_Turning_Radius'] = cars['Minimum_Turning_Radius'].replace(r'\D', '', regex=True)

# Renaming the column to provide a more descriptive name
cars.rename(columns={'Minimum_Turning_Radius': 'Minimum_Turning_Radius_meter'}, inplace=True)

# Converting the values in 'Minimum_Turning_Radius_meter' to float data type
cars['Minimum_Turning_Radius_meter'] = cars['Minimum_Turning_Radius_meter'].astype(float)

# %% [markdown]
# # **Handling Null Values**

# %% [markdown]
# Dealing with the NULL values present over the dataset.

# %% [markdown]
# Now, we produce summary statistics for the numerical columns in the updated '`cars`' DataFrame,

# %%
# Generate descriptive statistics for numerical columns in the updated 'cars' DataFrame
cars.describe()
# Out:
#        Ex-Showroom_Price_INR  Displacement_cc  Cylinders  Valves_Per_Cylinder  \
# count               1276.000         1264.000   1210.000             1174.000
# mean             4596537.887         1858.805      4.381                3.978
# std             12147346.945         1063.152      1.661                0.834
# min               236447.000           72.000      2.000                1.000
# 25%               743876.000         1198.000      4.000                4.000
# 50%              1060064.500         1497.000      4.000                4.000
# 75%              2979827.750         1998.000      4.000                4.000
# max            212155397.000         7993.000     16.000               16.000
#
#        Fuel_Tank_Capacity_litres  Height_mm  Length_mm  Width_mm    Doors  \
# count                   1207.000   1275.000   1276.000  1264.000 1272.000
# mean                      57.771   1592.540   4297.244  1790.009    4.550
# ...

# %% [markdown]
# This code prints the data type of each column in the '`cars`' DataFrame, providing a quick overview of the types of variables present in the dataset.

# %%
# Display the data type of each column in the 'cars' DataFrame
for i in cars.columns:
  print(i ,'------->', cars[i].dtype)
# Out:
# Make -------> object
# Model -------> object
# Variant -------> object
# Ex-Showroom_Price_INR -------> int32
# Displacement_cc -------> float64
# Cylinders -------> float64
# Valves_Per_Cylinder -------> float64
# Drivetrain -------> object
# Cylinder_Configuration -------> object
# Emission_Norm -------> object
# Engine_Location -------> object
# Fuel_System -------> object
# Fuel_Tank_Capacity_litres -------> float64
# Fuel_Type -------> object
# Height_mm -------> float64
# Length_mm -------> float64
# Width_mm -------> float64
# Body_Type -------> object
# Doors -------> float64
# ARAI_Certified_Mileage_kmpl -------> float64
# Kerb_Weight_kg -------> float64
# Gears -------> float64
# Ground_Clearance_mm -------> float64
# Front_Brakes -------> object
# Rear_Brakes -------> object
# Front_Suspension -------> object
# Rear_Suspension -------> object
# Front_Track_mm -------> float64
# Rear_Track_mm -------> float64
# F_Tire_Diameter_inch -------> float64
# ...

# %% [markdown]
# This code calculates the total number of missing values in the entire '`cars`' DataFrame.

# %%
# Sum of all missing values in the 'cars' DataFrame
cars.isnull().sum().sum()
# Out:
# 26364

# %% [markdown]
# In this code, missing values in numeric columns of the '`cars`' DataFrame are imputed with the median of each respective column.

# %%
# Impute missing values with the median for numeric columns in the 'cars' DataFrame
numeric=["int32","float64"]

for i in cars.columns:
    if cars[i].dtype in numeric:
        if cars[i].isnull().sum() > 0:
            cars[i]=cars[i].fillna(cars[i].median())

# %% [markdown]
# Here, we print the count of missing values in numeric columns of the '`cars`' DataFrame, providing insights into the remaining missing values after the imputation process.

# %%
# Display the count of missing values in numeric columns of the 'cars' DataFrame
for i in cars.columns:
    if cars[i].dtype in numeric:
        print(i,'-------->',cars[i].isnull().sum())
# Out:
# Ex-Showroom_Price_INR --------> 0
# Displacement_cc --------> 0
# Cylinders --------> 0
# Valves_Per_Cylinder --------> 0
# Fuel_Tank_Capacity_litres --------> 0
# Height_mm --------> 0
# Length_mm --------> 0
# Width_mm --------> 0
# Doors --------> 0
# ARAI_Certified_Mileage_kmpl --------> 0
# Kerb_Weight_kg --------> 0
# Gears --------> 0
# Ground_Clearance_mm --------> 0
# Front_Track_mm --------> 0
# Rear_Track_mm --------> 0
# F_Tire_Diameter_inch --------> 0
# F_Tire_Aspect_Ratio --------> 0
# F_Tire_Width_mm --------> 0
# R_Tire_Diameter_inch --------> 0
# R_Tire_Aspect_Ratio --------> 0
# R_Tire_Width_mm --------> 0
# Power_RPM --------> 0
# Power_PS --------> 0
# Torque_RPM --------> 0
# Torque_Nm --------> 0
# Seating_Capacity --------> 0
# Wheelbase_mm --------> 0
# Basic_Warranty_years --------> 0
# Boot_Space_litres --------> 0
# Minimum_Turning_Radius_meter --------> 0
# Number_of_Airbags --------> 0

# %% [markdown]
# This code calculates the total number of remaining missing values in the entire '`cars`' DataFrame after the imputation process.

# %%
# Sum of all remaining missing values in the 'cars' DataFrame
cars.isnull().sum().sum()
# Out:
# 22221

# %% [markdown]
# Here, we define a list named '`temp`' containing a subset of important columns selected from the '`cars`' DataFrame. These columns are considered vital for analysis and understanding the key features of the dataset.

# %%
# Selecting a subset of temp columns from the 'cars' DataFrame
temp = ['Make', 'Model', 'Variant', 'Ex-Showroom_Price_INR', 'Drivetrain', 'Cylinder_Configuration',
 'Emission_Norm', 'Engine_Location', 'Fuel_System', 'Fuel_Type', 'Body_Type', 'Front_Brakes', 'Rear_Brakes',
 'Front_Suspension', 'Rear_Suspension', 'Power_Steering', 'Power_Windows', 'Power_Seats', 'Odometer', 'Speedometer',
 'Seats_Material', 'Type']

# %% [markdown]
# In this code, missing values in the temp columns of the '`cars`' DataFrame are filled with the placeholder '`unspecified`' to handle any remaining null values.

# %%
# Fill missing values in temp columns with 'unspecified' in the 'cars' DataFrame
for i in temp:
    cars[i]=cars[i].fillna('unspecified')

# %% [markdown]
# This code calculates the total number of remaining missing values in the entire '`cars`' DataFrame after filling the temp columns with '`unspecified`'.

# %%
# Sum of all remaining missing values in the 'cars' DataFrame after filling with 'unspecified'
cars.isnull().sum().sum()
# Out:
# 21877

# %% [markdown]
# Here, we iterate through the columns of the '`cars`' DataFrame and append non-numeric features that are not part of the temp columns to the '`features`' list.

# %%
# Extract non-numeric features not included in the temp columns
features = []
for i in cars.columns:
    if i not in temp:
        if cars[i].dtype not in numeric:
            features.append(i)

# %% [markdown]
# Prints the first 5 non-numeric features from the '`features`' list, providing a glimpse of the selected non-numeric features.

# %%
# Display the first 5 non-numeric features
features[:5]
# Out:
# ['Keyless_Entry',
#  'Tachometer',
#  'Tripmeter',
#  'Start_/_Stop_Button',
#  '12v_Power_Outlet']

# %% [markdown]
# In this code, non-numeric features in the '`cars`' DataFrame are converted to binary indicators, where '`Yes`' indicates the presence of a value, and '`No`' indicates a missing value.

# %%
# Convert non-numeric features to binary indicators ('Yes' or 'No') in the 'cars' DataFrame
for k in features:
    cars[k] = np.where(cars[k].notnull(), 'Yes', cars[k])
    cars[k] = cars[k].fillna('No')

# %% [markdown]
# This code calculates the total number of remaining missing values in the entire '`cars`' DataFrame after converting non-numeric features to binary indicators ('`Yes`' or '`No`').

# %%
# Sum of all remaining missing values in the 'cars' DataFrame after converting to binary indicators
cars.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Viewing the final and cleaned data, saving it into `.csv` format

# %% [markdown]
# Here, the column names in the '`cars`' DataFrame are modified by replacing spaces with **underscores** and converting them to **lowercase** for consistency.

# %%
# Rename columns by replacing spaces with underscores and converting to lowercase
cars.columns = [col.replace(' ', '_').lower() for col in cars.columns]

# %% [markdown]
# Now, we take a look at a random sample of 5 rows from the modified '`cars`' DataFrame to observe the changes in column names.

# %%
cars.sample(5)
# Out:
#               make          model                  variant  \
# 273           Audi             A4     Premium Plus 35 Tfsi
# 544  Maruti Suzuki  Vitara Brezza                  Vdi Ags
# 915        Hyundai      Grand I10  1.2 Kappa Vtvt Magna At
# 209         Toyota    Etios Cross                       Gd
# 427  Maruti Suzuki          Swift                 Zdi Plus
#
#      ex-showroom_price_inr  displacement_cc  cylinders  valves_per_cylinder  \
# 273                4149000         1395.000      4.000                4.000
# 544                 864742         1248.000      4.000                4.000
# 915                 652328         1197.000      4.000                4.000
# 209                 766000         1364.000      4.000                2.000
# 427                 838000         1248.000      4.000                4.000
#
#     drivetrain cylinder_configuration emission_norm       engine_location  \
# 273       FWD                 In-line         BS IV  Front - Longitudinal
# ...

# %% [markdown]
# This code prints the data types of each column in the modified '`cars`' DataFrame, providing an overview of the data after the column name modifications.

# %%
# Display data types of each column in the modified 'cars' DataFrame
print(cars.dtypes)
# Out:
# make                         object
# model                        object
# variant                      object
# ex-showroom_price_inr         int32
# displacement_cc             float64
#                              ...
# rain_sensing_wipers          object
# leather_wrapped_steering     object
# automatic_headlamps          object
# asr_/_traction_control       object
# cruise_control               object
# Length: 117, dtype: object

# %% [markdown]
# Here, we print the total number of remaining missing values in the entire modified '`cars`' DataFrame after the data preparation steps.

# %%
print(cars.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# Now, we print the current shape of the modified '`cars`' DataFrame, indicating the number of rows and columns after the data preparation steps

# %%
cars.shape
# Out:
# (1276, 117)

# %% [markdown]
# This code prints concise information about the modified '`cars`' DataFrame, including **data types, non-null counts, and memory usage**.

# %%
# Display concise information about the modified 'cars' DataFrame
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 117 entries, make to cruise_control
# dtypes: float64(30), int32(1), object(86)
# memory usage: 1.1+ MB

# %% [markdown]
# Here, the modified '`cars`' DataFrame is saved to a **CSV file** named '`cars_data_cleaned.csv`' without including the index column.

# %%
# Save the modified 'cars' DataFrame to a CSV file named 'cars_data_cleaned.csv'
cars.to_csv('cars_data_cleaned.csv', index=False)

# %% [markdown]
# #**Statistics & Data Vizualization**

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# ### 1.1. Descriptive Numeric Analysis

# %% [markdown]
# ### 1.1. Descriptive Numeric Analysis

# %%
# Generate descriptive statistics for numerical columns in the 'cars' DataFrame
cars.describe()
# Out:
#        ex-showroom_price_inr  displacement_cc  cylinders  valves_per_cylinder  \
# count               1276.000         1276.000   1276.000             1276.000
# mean             4596537.887         1855.402      4.361                3.980
# std             12147346.945         1058.714      1.620                0.800
# min               236447.000           72.000      2.000                1.000
# 25%               743876.000         1198.000      4.000                4.000
# 50%              1060064.500         1497.000      4.000                4.000
# 75%              2979827.750         1998.000      4.000                4.000
# max            212155397.000         7993.000     16.000               16.000
#
#        fuel_tank_capacity_litres  height_mm  length_mm  width_mm    doors  \
# count                   1276.000   1276.000   1276.000  1276.000 1276.000
# mean                      57.134   1592.512   4297.244  1789.821    4.552
# ...

# %% [markdown]
# **Observation:**<br>
# Here we get a statistical data for all the numerics value such as the price, dimensions of body and tire, capacity, power and torque.

# %% [markdown]
# ### 1.2. Descriptive Object Analysis

# %% [markdown]
# This code generates descriptive statistics for categorical columns in the '`cars`' DataFrame, including **count, unique values, top value, and frequency**.

# %%
# Generate descriptive statistics for categorical columns in the 'cars' DataFrame
cars.describe(include=['object'])
# Out:
#                  make  model variant drivetrain cylinder_configuration  \
# count            1276   1276    1276       1276                   1276
# unique             41    263    1064          5                      5
# top     Maruti Suzuki  Nexon     Lxi       FWD                 In-line
# freq              149     24       9        887                   1077
#
#        emission_norm     engine_location fuel_system fuel_type body_type  \
# count           1276                1276        1276      1276      1276
# unique             4                   8           3         6        18
# top            BS IV  Front - Transverse   Injection    Petrol       SUV
# freq             879                 804        1264       643       447
#
#            front_brakes rear_brakes      front_suspension   rear_suspension  \
# count              1276        1276                  1276              1276
# unique                4           4                    17                66
# ...

# %% [markdown]
# **Observation:**<br>
# This type of description shows the frequency of each column which is object, their frequency and the leader for every column.

# %% [markdown]
# ### 2. Top Car Models

# %% [markdown]
# Here, we calculate the average `ex-showroom price` for each car model, group the data by `make and model`, and then display the top 5 car models based on the **highest average ex-showroom price.**

# %%
# Find and display the top 5 car models based on the ex-showroom price
top_car_models = cars.groupby(['make', 'model'])['ex-showroom_price_inr'].mean().sort_values(ascending=False).head(5)
print("Top Car Models:\n", top_car_models)
# Out:
# Top Car Models:
#  make         model
# Bugatti      Chiron                       202149167.000
# Rolls-Royce  Rolls-Royce Phantom           85200000.000
#              Rolls-Royce Drophead Coupe    83755383.000
#              Rolls-Royce Phantom Coupe     77312661.000
#              Rolls-Royce Cullinan          69500000.000
# Name: ex-showroom_price_inr, dtype: float64

# %% [markdown]
# **Observation:**<br>
# In India, the leading car Bugatti is a super sports car, and the other 4 are known for luxury.

# %% [markdown]
# ### 3. Cheapest Car Models

# %% [markdown]
# Here, we calculate the average `ex-showroom price` for each car `model`, group the data by `make and model`, and then display the 5 cheapest car models based on the **lowest average ex-showroom price.**

# %%
# Find and display the cheap 5 car models based on the ex-showroom price
cheapest_car_models = cars.groupby(['make', 'model'])['ex-showroom_price_inr'].mean().sort_values(ascending=True).head(5)
print("Top Car Models:\n", cheapest_car_models)
# Out:
# Top Car Models:
#  make           model
# Bajaj          Qute (Re60)     273000.000
# Maruti Suzuki  Omni            283631.500
# Tata           Nano Genx       291263.500
# Maruti Suzuki  Alto 800 Tour   355397.000
# Datsun         Redi-Go         358994.333
# Name: ex-showroom_price_inr, dtype: float64

# %% [markdown]
# **Observation:**<br>
# Bajaj Qute is a most pocket friendly car. <br> Omni is best known for ambulance, Nano Genx and Datsun are now obsolete. <br> However Alto is know popularly for affordable cab services.

# %% [markdown]
# ### 4. Popular Fuel Types

# %% [markdown]
# In this step, we identify and display the **top 5 most** popular fuel types based on their count in the '`cars`' DataFrame.

# %%
# Find and display the most popular fuel types based on the count
popular_fuel_types = cars['fuel_type'].value_counts().head(5).reset_index()
print("Popular Fuel Types:\n", popular_fuel_types)
# Out:
# Popular Fuel Types:
#    fuel_type  count
# 0    Petrol    643
# 1    Diesel    582
# 2       CNG     16
# 3    Hybrid     15
# 4  Electric     14

# %% [markdown]
# **Observation:**<br>
# Seems like people of India sticks with more Petrol and Diesel Variants. However it is concerning as we really need to switch over more renewable source.

# %% [markdown]
# ### 5. Seating Capacity Insights

# %% [markdown]
# Here, we analyze seating capacity characteristics by calculating the **average** `ex-showroom price` for each seating capacity category in the '`cars`' DataFrame.

# %%
# Explore seating capacity characteristics
seating_capacity_insights = cars.groupby('seating_capacity')['ex-showroom_price_inr'].mean()
print("Seating Capacity Insights:\n", seating_capacity_insights)
# Out:
# Seating Capacity Insights:
#  seating_capacity
# 2.000    37209609.436
# 4.000    18033302.614
# 5.000     2485557.853
# 6.000     1576018.231
# 7.000     4259064.082
# 8.000     1175828.588
# 9.000     1099911.737
# 16.000    1205000.000
# Name: ex-showroom_price_inr, dtype: float64

# %% [markdown]
# **Observation:**<br>
# 2 Seater always means a sports car. so it will always be high. 16 seater seems like more suspicious, maybe its a Traveller

# %% [markdown]
# ### 6. Fuel Efficiency Analysis

# %% [markdown]
# In this analysis, we calculate the average `ARAI certified mileage` for each fuel type in the '`cars`' DataFrame to understand fuel efficiency characteristics.

# %%
# Analyze fuel efficiency based on ARAI certified mileage
fuel_efficiency_analysis = cars.groupby('fuel_type')['arai_certified_mileage_kmpl'].mean()
print("Fuel Efficiency Analysis:\n", fuel_efficiency_analysis)
# Out:
# Fuel Efficiency Analysis:
#  fuel_type
# CNG            28.672
# CNG + Petrol   22.323
# Diesel         19.374
# Electric       18.190
# Hybrid         16.790
# Petrol         17.195
# Name: arai_certified_mileage_kmpl, dtype: float64

# %% [markdown]
# **Observation:**<br>
# Its a surprise that Indian Dads still stick with petrol or diesel for better mileage. <br> Rather they should shitch to CNG for better mileage.

# %% [markdown]
# ### 7. Outliers Detection

# %% [markdown]
# This code identifies and examines **outliers** in all numeric columns of the '`cars`' DataFrame by comparing values that exceed the **mean plus 3 times the standard deviation**. It then prints the values of outliers for each numeric column.

# %%
# Identify and examine outliers in all numeric columns
numeric_columns = cars.select_dtypes(include=['number']).columns

outliers = {}
for column in numeric_columns:
    # Filter values where they exceed the mean plus 3 times the standard deviation
    column_outliers = cars.loc[cars[column] > cars[column].mean() + 3 * cars[column].std(), column].values
    outliers[column] = column_outliers

# Print values of outliers for each numeric column
for column, values in outliers.items():
    print(f"Values of Outliers in {column}:\n", values)
# Out:
# Values of Outliers in ex-showroom_price_inr:
#  [ 45941557  42531500  46709733  53247201  50025840  52571294  69500000
#   77312661 192142937 212155397  42000000  52000000  47893943  53210327
#   47467700  59216193  83755383  52000000  43367500  95000000  75400000]
# Values of Outliers in displacement_cc:
#  [6417. 5461. 6592. 5980. 5204. 5998. 5950. 5198. 6593. 6592. 6592. 6752.
#  6750. 6749. 7993. 7993. 5461. 5204. 5204. 5204. 5204. 5204. 5204. 5204.
#  5204. 5204. 6262. 6498. 6498. 6498. 6598. 6749. 5935. 6496. 5700. 6749.
#  6749. 5998.]
# Values of Outliers in cylinders:
#  [12. 12. 10. 12. 12. 12. 12. 12. 12. 12. 12. 12. 16. 16. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 12. 12. 12. 12. 12. 12. 12. 12. 12. 12.]
# Values of Outliers in valves_per_cylinder:
#  [12. 12. 16. 16.  8.  8. 12. 12.  8.  8.]
# Values of Outliers in fuel_tank_capacity_litres:
#  [609. 935. 935. 935. 935. 825. 825. 675. 905.]
# Values of Outliers in height_mm:
#  [2055. 2055. 2075. 2075. 2055. 2055. 2670.]
# ...

# %% [markdown]
# **Observation:**<br>
# Some cars might have an outlying feature, but that doesn't mean they doesn't exist. <br> They exist! But they are special.

# %% [markdown]
# ### 8. Average Price by Make

# %% [markdown]
# In this step, we calculate and display the `average ex-showroom price` for each car make in the '`cars`' DataFrame, providing insights into pricing trends across different makes.

# %%
# Calculate and display the average ex-showroom price for each car make
average_price_by_make = cars.groupby('make')['ex-showroom_price_inr'].mean()
print("Average Ex-showroom Price by Make:\n", average_price_by_make)
# Out:
# Average Ex-showroom Price by Make:
#  make
# Aston Martin     36267442.000
# Audi              7240430.645
# Bajaj              273000.000
# Bentley          40565854.333
# Bmw               8256216.216
# Bugatti         202149167.000
# Datsun             450907.667
# Dc                3407407.000
# Ferrari          42872495.625
# Fiat               779556.348
# Force             1150500.000
# Ford              1123853.814
# Go+                571355.000
# Honda             1206136.562
# Hyundai            987476.546
# Icml               970082.909
# Isuzu             2225392.800
# Jaguar           10464503.045
# Jeep              3203428.071
# Kia               1701142.857
# Lamborghini      39053919.231
# Land Rover       14294469.541
# Lexus            15015300.000
# Mahindra          1105725.420
# Maruti Suzuki      688808.362
# Maruti suzuki      515128.714
# Maserati         15696889.889
# Mercedes-Benz     9479081.544
# Mg                1610307.692
# ...

# %% [markdown]
# **Observation:**<br>
# This showcases the average price that a brand offers to a customer.

# %% [markdown]
# ### 9. Price Segmentation

# %% [markdown]
# Reference: [Pd.Cut](https://www.geeksforgeeks.org/how-to-use-pandas-cut-and-qcut/)<br>
# Reference: [Unstack](https://www.geeksforgeeks.org/pandas-groupby-unstack/)

# %% [markdown]
# Here, we define price ranges for segmentation based on ex-showroom prices, create a new column 'price_segment' in the 'cars' DataFrame, and then calculate and display the average ex-showroom price for each car make within each price segment.

# %%
# Define price ranges for segmentation
super_expensive_range = (cars['ex-showroom_price_inr'] > 5000000)
expensive_range = ((cars['ex-showroom_price_inr'] <= 5000000) & (cars['ex-showroom_price_inr'] > 2000000))
affordable_range = (cars['ex-showroom_price_inr'] <= 2000000)

# Create a new column 'price_segment' based on the defined ranges
cars['price_segment'] = pd.cut(cars['ex-showroom_price_inr'], bins=[0, 2000000, 5000000, float('inf')],
                              labels=['Affordable', 'Expensive', 'Super Expensive'], right=False)

# Calculate and display the average ex-showroom price for each car make within each price segment
cars.groupby(['price_segment', 'make'])['ex-showroom_price_inr'].mean().unstack().transpose()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\3216187399.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cars['price_segment'] = pd.cut(cars['ex-showroom_price_inr'], bins=[0, 2000000, 5000000, float('inf')],
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\3216187399.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cars.groupby(['price_segment', 'make'])['ex-showroom_price_inr'].mean().unstack().transpose()
# price_segment  Affordable   Expensive  Super Expensive
# make
# Aston Martin          NaN         NaN     36267442.000
# ...

# %% [markdown]
# **Observation:**<br>
# Alert the Indian Dads! They need this before they start dreaming of buying luxury cars. It’ll help them sort out their aspirations.

# %% [markdown]
# ### 10. Model manufactured by Each Maker

# %% [markdown]
# This code creates a new DataFrame, `unique_models_per_make`, that lists unique car `models` for each make. The models are sorted and presented as comma-separated strings. This provides a concise overview of distinct car models associated with each make.

# %%
# Create a new DataFrame with unique models per make
unique_models_per_make = cars.groupby('make')['model'].unique().apply(lambda x: ', '.join(sorted(x))).reset_index()

# Display the unique models per make
print("Unique Models per Make:\n", unique_models_per_make)
# Out:
# Unique Models per Make:
#               make                                              model
# 0    Aston Martin                             Db 11, Rapide, Vantage
# 1            Audi  A3, A3 Cabriolet, A4, A5, A5 Cabriolet, A6, A8...
# 2           Bajaj                                        Qute (Re60)
# 3         Bentley    Bentayga, Continental Gt, Flying Spur, Mulsanne
# 4             Bmw  3-Series, 5-Series, 6-Series, 7-Series, M2 Com...
# 5         Bugatti                                             Chiron
# 6          Datsun                                        Go, Redi-Go
# 7              Dc                                             Avanti
# 8         Ferrari  458 Speciale, 458 Spider, 488 Gtb, 812 Superfa...
# 9            Fiat  Abarth Avventura, Abarth Punto, Avventura, Lin...
# 10          Force                                             Gurkha
# 11           Ford  Aspire, Ecosport, Endeavour, Figo, Freestyle, ...
# ...

# %% [markdown]
# **Observation:**<br>
# This showcases the different models that every car brand offers to customer.

# %% [markdown]
# ### 11. Feature-Rich Cars

# %% [markdown]
# This code creates a '`num_features`' column in the '`cars`' DataFrame, counting the '`Yes`' values across a list of car features. This allows for a concise **numerical representation** of the number of features in each car.

# %%
# List of features (lowercased)
features = [
    'keyless_entry', 'tachometer', 'tripmeter', 'start_/_stop_button', '12v_power_outlet', 'audiosystem',
    'aux-in_compatibility', 'average_fuel_consumption', 'bluetooth', 'boot-lid_opener', 'cd_/_mp3_/_dvd_player',
    'central_locking', 'child_safety_locks', 'clock', 'cup_holders', 'distance_to_empty', 'door_pockets',
    'engine_malfunction_light', 'fm_radio', 'fuel-lid_opener', 'fuel_gauge', 'handbrake', 'instrument_console',
    'low_fuel_warning', 'multifunction_display', 'sun_visor', 'third_row_ac_vents', 'ventilation_system',
    'auto-dimming_rear-view_mirror', 'hill_assist', 'gear_indicator', 'engine_immobilizer', 'seat_back_pockets',
    'abs_(anti-lock_braking_system)', 'headlight_reminder', 'adjustable_headrests', 'gross_vehicle_weight', 'airbags',
    'door_ajar_warning', 'ebd_(electronic_brake-force_distribution)', 'fasten_seat_belt_warning', 'gear_shift_reminder',
    'adjustable_steering_column', 'parking_assistance', 'key_off_reminder', 'usb_compatibility', 'cigarette_lighter',
    'infotainment_screen', 'multifunction_steering_wheel', 'average_speed', 'eba_(electronic_brake_assist)',
    'seat_height_adjustment', 'navigation_system', 'second_row_ac_vents', 'rear_center_armrest', 'ipod_compatibility',
    'esp_(electronic_stability_program)', 'cooled_glove_box', 'turbocharger', 'isofix_(child-seat_mount)',
    'rain_sensing_wipers', 'leather_wrapped_steering', 'automatic_headlamps', 'asr_/_traction_control', 'cruise_control'
]

# Create a new column 'num_features' with the count of 'Yes' values for each row
cars['num_features'] = cars[features].apply(lambda row: row.eq('Yes').sum(), axis=1)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\1206441002.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cars['num_features'] = cars[features].apply(lambda row: row.eq('Yes').sum(), axis=1)

# %% [markdown]
# In this step, we identify and display the **top 20 cars** in the '`cars`' DataFrame based on the number of features, showcasing cars with a higher number of features.

# %%
# Find and display the top 20 cars with more features
top_cars_more_features = cars.sort_values(by='num_features', ascending=False).head(20)[['make', 'model', 'ex-showroom_price_inr', 'num_features']]
print("Top 20 Cars with More Features:\n", top_cars_more_features)
# Out:
# Top 20 Cars with More Features:
#             make             model  ex-showroom_price_inr  num_features
# 817        Audi                Q7                7711500            65
# 265        Audi                Q3                4361000            65
# 816        Audi                Q7                8111500            65
# 839      Jaguar                Xj               11129599            65
# 246       Skoda  Superb Sportline                2899599            65
# 247       Skoda  Superb Sportline                3149599            65
# 792  Land Rover      Range Evoque                5985000            65
# 791  Land Rover      Range Evoque                5494000            65
# 790  Land Rover      Range Evoque                5985000            65
# 789  Land Rover      Range Evoque                5494000            65
# 259       Skoda            Kodiaq                3299599            65
# 260       Skoda            Kodiaq                3678599            65
# ...

# %% [markdown]
# **Observation:**<br>
# Got money to splurge? Check out the Jaguar XJ. If not, the Skoda Superb is a great choice!

# %% [markdown]
# ### 12. Cars with Less Features

# %% [markdown]
# Here, we identify and display the last 5 cars in the '`cars`' DataFrame based on the `number of features`, showcasing cars with a lower number of features

# %%
# Find and display the last 5 cars with less features
cars_less_features = cars.sort_values(by='num_features', ascending=False).tail(5)[['make', 'model', 'ex-showroom_price_inr', 'num_features']]
print("5 Cars with Less Features:\n", cars_less_features)
# Out:
# 5 Cars with Less Features:
#                 make                              model  ex-showroom_price_inr  \
# 536        Mahindra                  Bolero Power Plus                 859497
# 82          Premier                                Rio                 568623
# 353     Rolls-Royce               Rolls-Royce Cullinan               69500000
# 1162         Jaguar                             F-Type               23659454
# 862   Mercedes-Benz  Mercedes-Benz Amg Gt 4-Door Coupe               24200000
#
#       num_features
# 536             14
# 82              12
# 353              8
# 1162             7
# 862              6

# %% [markdown]
# **Observation:**<br>
# If you want to waste money with less features, regret buying Rolls Royce Cullinan. <br> Else buy Mahindra Bolero.

# %% [markdown]
# ## **Data Vizualization: `Univariate`**

# %% [markdown]
# ### 1. **Histogram**

# %% [markdown]
# Here, we create a side-by-side histogram subplot for the `distribution of ex-showroom prices` and the `count of features` in the '`cars`' DataFrame. The first subplot uses a log scale for better visualization of ex-showroom prices.

# %%
# Create a side-by-side histogram subplot for sales and days to ship
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# First subplot for sales distribution
log_bins = np.logspace(np.log10(cars['ex-showroom_price_inr'].min()), np.log10(cars['ex-showroom_price_inr'].max()), 20)
axes[0].hist(cars['ex-showroom_price_inr'], bins=log_bins, color='skyblue', edgecolor='black')
axes[0].set_title('Distribution of Ex-showroom Prices')
axes[0].set_xlabel('Ex-showroom Price (INR)')
axes[0].set_ylabel('Frequency')
axes[0].set_xscale('log')  # Set x-axis to log scale

# Second subplot for the count of features
sns.histplot(cars['num_features'], bins=30, color='lightgreen', edgecolor='black', ax=axes[1])
axes[1].set_title('Histogram of Features Count')
axes[1].set_xlabel('Number of Features')
axes[1].set_ylabel('Frequency')

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation:**<br>
# 1. Plot 1 shows that the Indian car market is more focused on affordable range which is 10 Lacs.
# 2. Plot 2 shows that most of the Indian cars have more than 30 features in their car. Yes, India do want to get an industry ready modified and featured car.

# %% [markdown]
# ### 2. **Bar Charts**

# %% [markdown]
# Reference: [.idmax()](https://stackoverflow.com/questions/46217537/choose-between-two-values-and-set-the-most-frequent-in-a-pandas-dataframe)

# %% [markdown]
# This code creates a side-by-side bar plot with two subplots. The first subplot shows the `count of car makes` to visualize the `diversity` of car makes. The second subplot displays the `count of variants` for the `top-diverse model` from each `make`.

# %%
# Create a side-by-side bar plot for car makes and top-diverse models
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# First subplot for car makes
sns.countplot(data=cars, x='make', palette='viridis', order=cars['make'].value_counts().index, ax=axes[0])
axes[0].set_title('Count of Diversity of Car Makes')
axes[0].set_xlabel('Car Make')
axes[0].set_ylabel('Total Count they Offer')
axes[0].tick_params(axis='x', rotation=90)

# Identify the top-diverse model for each make
top_models_by_make = cars.groupby('make')['model'].apply(lambda x: x.value_counts().idxmax())

# Filter the car DataFrame to include only the rows corresponding to the top-selling models
top_diverse_cars = cars[cars['model'].isin(top_models_by_make)]

# Second subplot for top-diverse models
sns.countplot(data=top_diverse_cars, x='model', order=top_diverse_cars['model'].value_counts().index, palette='viridis', ax=axes[1])
axes[1].set_title('Top-Diverse Model from Each Make')
axes[1].set_xlabel('Car Model')
axes[1].set_ylabel('Counts of Variants')
axes[1].tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:**<br>
# 1. This was expected! Indian dad's trust is always Maruti Suzuki! Who's DC anyway? The one who created Tarzan the wonder car?
# 2. Well Never know Ranjit sir would offer so much variants in Nexon. Anyways Avanti is an overrated modified car for me.

# %% [markdown]
# Now we calculats the `counts` of car makes and price segments, then create a `stacked bar chart` using Plotly to visualize the distribution of makes across different price segments.

# %%
# Calculate the counts of makes and price segments
make_counts = cars.groupby(['make', 'price_segment']).size().reset_index(name='count')

# Sort the makes in descending order based on the total count
sorted_makes = make_counts.groupby('make')['count'].sum().sort_values(ascending=False).index

# Create a stacked bar chart using plotly
fig = px.bar(make_counts, x='make', y='count', color='price_segment', title='Counts of Makes by Price Segment',
             labels={'make': 'Make', 'count': 'Count', 'price_segment': 'Price Segment'}, height=500,
             category_orders={'make': sorted_makes})

# Customize the layout
fig.update_layout(xaxis=dict(tickangle=-45, tickmode='array', tickvals=list(range(len(sorted_makes))),
                             ticktext=sorted_makes))

# Show the chart
fig.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\3683384975.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   make_counts = cars.groupby(['make', 'price_segment']).size().reset_index(name='count')
# c:\Users\varun\anaconda3\Lib\site-packages\plotly\express\_core.py:1958: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(required_grouper, sort=False)  # skip one_group groupers

# %% [markdown]
# **Observation:**<br>
# Well we can now see, why Indians prefer Maruti, Hyundai, Mahindra, Tata, Toyota and Honda! Its super affordable! Also we can see them everywhere on Indian roads.

# %% [markdown]
# Here, we define the `desired body types`, filter the DataFrame to include only those body types, and then create side-by-side bar charts for `fuel type` and the `distribution of desired body types`. The y-axis is displayed on a log scale for better visualization.

# %%
# Define the desired body types
desired_body_types = ['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV']

# Filter the DataFrame to include only the desired body types
filtered_car = cars[cars['body_type'].isin(desired_body_types)]

# Create side-by-side bar charts for fuel type and body type distribution
fig, axes = plt.subplots(1, 2, figsize=(16, 4))

# Bar chart for fuel type distribution
sns.countplot(data=cars, x='fuel_type',width = 0.5, order=cars['fuel_type'].value_counts().index, palette='viridis', ax=axes[0])
axes[0].set_yscale('log')
axes[0].set_title('Count of Cars by Fuel Type')
axes[0].set_xlabel('Fuel Type')
axes[0].set_ylabel('Count (log scale)')

# Bar chart for filtered body type distribution
sns.countplot(data=filtered_car, x='body_type', order=filtered_car['body_type'].value_counts().index, palette='viridis', ax=axes[1])
axes[1].set_yscale('log')
axes[1].set_title('Count of Cars by Desired Body Types')
axes[1].set_xlabel('Body Type')
axes[1].set_ylabel('Count (log scale)')

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:**<br>
# 1. Petrol and diesel is still preferred in India by lot.
# 2. Nowadays there is hype of SUV and Sedan, people of India prefere more spacious car. I rather see more SUVs and sedans nowadays

# %% [markdown]
# ### 3. **Box Plots**

# %% [markdown]
# Here, we create a 2x2 matrix of box plots for different features in the '`cars`' DataFrame, showcasing the distribution and `variability of ex-showroom prices`, `ARAI certified mileage`, `number of cylinders`, and `number of doors`. The x-axis for ex-showroom prices is displayed on a log scale for better visualization.

# %%
# Create a 2x2 matrix of box plots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Box plot for ex-showroom prices
sns.boxplot(data=cars, x='ex-showroom_price_inr', color='lightblue', ax=axes[0, 0])
axes[0, 0].set_xscale('log')
axes[0, 0].set_title('Ex-showroom Prices')
axes[0, 0].set_xlabel('Ex-showroom Price (INR)')

# Box plot for ARAI certified mileage
sns.boxplot(data=cars, x='arai_certified_mileage_kmpl', color='lightgreen', ax=axes[0, 1])
axes[0, 1].set_title('ARAI Certified Mileage (kmpl)')
axes[0, 1].set_xlabel('ARAI Certified Mileage (kmpl)')

# Box plot for cylinders
sns.boxplot(data=cars, x='cylinders', color='lightcoral', ax=axes[1, 0])
axes[1, 0].set_title('Cylinders')
axes[1, 0].set_xlabel('Number of Cylinders')

# Box plot for doors
sns.boxplot(data=cars, x='doors', color='lightskyblue', ax=axes[1, 1])
axes[1, 1].set_title('Doors')
axes[1, 1].set_xlabel('Number of Doors')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. **Pie Charts**

# %% [markdown]
# Reference: [Function](https://stackoverflow.com/questions/61283620/calling-pandas-apply-function-on-results-of-a-mask)
# <br>In this function, we take a data series and a `threshold percentage` as inputs. The function calculates the **percentages of each category** in the series and creates **a mask to identify categories exceeding the specified threshold percentage**. Categories below the threshold are grouped into '`Others`,' and the resulting grouped series is returned.

# %%
# Function to group small percentages into 'Other'
def group_small_percentages(data_series, threshold_percent=10):
    percentages = data_series.value_counts(normalize=True) * 100
    mask = percentages >= threshold_percent
    grouped_series = data_series.apply(lambda x: x if mask.get(x, False) else 'Others')
    return grouped_series

# %% [markdown]
# In this code, we remove '`unspecified`' values from each column in the '`cars`' DataFrame and then create a 2x2 matrix of pie charts to visualize the distribution of `drivetrain types`, `emission norms`, `fuel types`, and `desired body types` in the market. The '`group_small_percentages`' function is utilized to handle small percentages and group them into 'Others' for better visualization.

# %%
# Remove 'unspecified' values from each column
car_no_unspecified = cars.replace('unspecified', np.nan).dropna()

# Create a 2x2 matrix for pie charts
plt.figure(figsize=(10, 8))

# Pie chart for Drivetrain
plt.subplot(2, 2, 1)
drivetrain_distribution = car_no_unspecified['drivetrain'].value_counts()
plt.pie(drivetrain_distribution, labels=drivetrain_distribution.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
plt.title('Distribution of Drivetrain Types')
plt.legend(loc='lower left', fontsize='small')

# Pie chart for Emission Norm
plt.subplot(2, 2, 2)
emission_norm_distribution = car_no_unspecified['emission_norm'].value_counts()
plt.pie(emission_norm_distribution, labels=emission_norm_distribution.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
plt.title('Distribution of Emission Norms')
plt.legend(loc='lower left', fontsize='small')

# Pie chart for Fuel Type
plt.subplot(2, 2, 3)
fuel_type_distribution = group_small_percentages(car_no_unspecified['fuel_type'])
plt.pie(fuel_type_distribution.value_counts(), labels=fuel_type_distribution.value_counts().index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
plt.title('Distribution of Fuel Types')
plt.legend(loc='lower left', fontsize='small')

# Pie chart for Desired Body Types
plt.subplot(2, 2, 4)
body_type_distribution = group_small_percentages(filtered_car['body_type'])
plt.pie(body_type_distribution.value_counts(), labels=body_type_distribution.value_counts().index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
plt.title('Distribution of Desired Body Types in the Market')
plt.legend(loc='lower left', fontsize='small')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:**<br>
# 1. Most cars in India are Forward and Rear wheel drive due to even terrain. 4 Wheel Drive is only required for long trekking such as Leh - Ladakh trip.
# 2. Most cars of India is BS4, which is more harmful for nature, however its preferred to use BS6.
# 3. Petrols and diesels are always first priority of Indian Dads!
# 4. India grows the hype of SUVs and Sedans, more than Hatchbacks.

# %% [markdown]
# Here, we are visualizing the distribution of the top 6 car `makes` and market-dominating car models using pie charts. The first subplot shows the `distribution of the top 6 car makes`, while the second subplot illustrates the `distribution of the top 6 market-dominating` car models.

# %%
# Select the top 6 makes and market-dominating models based on counts
top_makes = cars['make'].value_counts().head(6)
top_models = cars['model'].value_counts().head(6)

# Create a 1x2 matrix of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot the pie chart for top makes in the first subplot (axes[0])
axes[0].pie(top_makes, labels=top_makes.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
axes[0].set_title('Distribution of Top 6 Car Makes')

# Plot the pie chart for top models in the second subplot (axes[1])
axes[1].pie(top_models, labels=top_models.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('crest'))
axes[1].set_title('Distribution of Top 6 Market Dominating Car Models')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# **Observation:**<br>
# 1. Maruti Suzuki and Hyundai shares more market in India
# 2. Tata Nexon didn't let us leave with a doubt of the toughest competitor in Indian Market

# %% [markdown]
# ### 5. **Count Plots**

# %% [markdown]
# Here, we create a 3x3 matrix of subplots to visualize count plots for various categorical columns in the '`cars`' DataFrame. Each subplot focuses on different aspects like `drivetrain`, `fuel type`, `cylinder configuration`, `engine location`, `number of doors`, `number of gears`, `transmission type`, and `body type`. The use of logarithmic scale on the y-axis enhances visibility.

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Count plot for drivetrain
sns.countplot(data=car_no_unspecified, x='drivetrain', ax=axes[0, 0], palette='viridis', order=car_no_unspecified['drivetrain'].value_counts().index, width=0.5)
axes[0, 0].set_title('Count of Cars by Drivetrain')
axes[0, 0].set_xlabel('Drivetrain')
axes[0, 0].set_yscale('log')

# Count plot for fuel type
sns.countplot(data=car_no_unspecified, x='fuel_type', ax=axes[0, 1], palette='viridis', order=car_no_unspecified['fuel_type'].value_counts().index, width=0.5)
axes[0, 1].set_title('Count of Cars by Fuel Type')
axes[0, 1].tick_params(axis='x', rotation=90)
axes[0, 1].set_xlabel('Fuel Type')
axes[0, 1].set_yscale('log')

# Count plot for cylinder configuration
sns.countplot(data=car_no_unspecified, x='cylinder_configuration', ax=axes[0, 2], palette='viridis', order=car_no_unspecified['cylinder_configuration'].value_counts().index, width=0.5)
axes[0, 2].set_title('Count of Cars by Cylinder Configuration')
axes[0, 2].set_xlabel('Cylinder Configuration')
axes[0, 2].set_yscale('log')

# Count plot for engine location
sns.countplot(data=car_no_unspecified, x='engine_location', ax=axes[1, 0], palette='viridis', order=car_no_unspecified['engine_location'].value_counts().index, width=0.5)
axes[1, 0].set_title('Count of Cars by Engine Location')
axes[1, 0].tick_params(axis='x', rotation=90)
axes[1, 0].set_xlabel('Engine Location')
axes[1, 0].set_yscale('log')

# Count plot for doors
sns.countplot(data=car_no_unspecified, x='doors', ax=axes[1, 1], palette='viridis', order=car_no_unspecified['doors'].value_counts().index, width=0.5)
axes[1, 1].set_title('Count of Cars by Number of Doors')
axes[1, 1].set_xlabel('Number of Doors')
axes[1, 1].set_yscale('log')

# Count plot for gears
sns.countplot(data=car_no_unspecified, x='gears', ax=axes[1, 2], palette='viridis', order=car_no_unspecified['gears'].value_counts().index, width=0.5)
axes[1, 2].set_title('Count of Cars by Number of Gears')
axes[1, 2].set_xlabel('Number of Gears')
axes[1, 2].set_yscale('log')

# Count plot for type
sns.countplot(data=car_no_unspecified, x='type', ax=axes[2, 0], palette='viridis', order=car_no_unspecified['type'].value_counts().index, width=0.5)
axes[2, 0].set_title('Count of Cars by Transmission Type')
axes[2, 0].set_xlabel('Transmission Type')
axes[2, 0].set_yscale('log')

# Count plot for body type
sns.countplot(data=filtered_car, x='body_type', ax=axes[2, 1], palette='viridis', order=filtered_car['body_type'].value_counts().index, width=0.5)
axes[2, 1].set_title('Count of Cars by Body Type')
axes[2, 1].tick_params(axis='x', rotation=90)
axes[2, 1].set_xlabel('Body Type')
axes[2, 1].set_yscale('log')

# Hide the empty subplot in the last row and last column
axes[2, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Data Vizualization: `Bivariate`**

# %% [markdown]
# ### 1. **Correlation Matrix**

# %% [markdown]
# Here, we select specific dimensions (`height`, `length`, `width`, `kerb weight`, and `ground clearance`) from the '`cars`' DataFrame and calculate the correlation matrix. The resulting matrix shows the correlation coefficients between these dimensions.

# %%
# Select the dimensions and calculate the correlation matrix
dimension_subset = cars[['height_mm', 'length_mm', 'width_mm', 'kerb_weight_kg', 'ground_clearance_mm']].corr()

# Display the correlation matrix
dimension_subset
# Out:
#                      height_mm  length_mm  width_mm  kerb_weight_kg  \
# height_mm                1.000      0.149     0.202          -0.043
# length_mm                0.149      1.000     0.757          -0.062
# width_mm                 0.202      0.757     1.000          -0.059
# kerb_weight_kg          -0.043     -0.062    -0.059           1.000
# ground_clearance_mm      0.204      0.166     0.289          -0.012
#
#                      ground_clearance_mm
# height_mm                          0.204
# length_mm                          0.166
# width_mm                           0.289
# kerb_weight_kg                    -0.012
# ground_clearance_mm                1.000

# %% [markdown]
# **Observation:**<br>
# Dimesions of car that is really required

# %% [markdown]
# In this section, we choose specific columns related to `tire features` from the '`cars`' DataFrame and compute the correlation matrix. The resulting matrix displays the correlation coefficients between these `tire-related dimensions`.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_tire = cars[['front_track_mm', 'rear_track_mm', 'f_tire_diameter_inch', 'f_tire_aspect_ratio',
                               'f_tire_width_mm', 'r_tire_diameter_inch', 'r_tire_aspect_ratio', 'r_tire_width_mm']].corr()

# Display the correlation matrix
correlation_matrix_tire
# Out:
#                       front_track_mm  rear_track_mm  f_tire_diameter_inch  \
# front_track_mm                 1.000          1.000                 0.047
# rear_track_mm                  1.000          1.000                 0.045
# f_tire_diameter_inch           0.047          0.045                 1.000
# f_tire_aspect_ratio           -0.022         -0.021                -0.565
# f_tire_width_mm                0.048          0.047                 0.866
# r_tire_diameter_inch           0.047          0.045                 0.999
# r_tire_aspect_ratio           -0.025         -0.024                -0.760
# r_tire_width_mm                0.041          0.039                 0.879
#
#                       f_tire_aspect_ratio  f_tire_width_mm  \
# front_track_mm                     -0.022            0.048
# rear_track_mm                      -0.021            0.047
# f_tire_diameter_inch               -0.565            0.866
# f_tire_aspect_ratio                 1.000           -0.466
# ...

# %% [markdown]
# **Observation:**<br>
# Tires also matter for the roads full of potholes.

# %% [markdown]
# Here, we choose specific columns related to `power` and `torque` from the '`cars`' DataFrame and compute the correlation matrix. The resulting matrix shows the correlation coefficients between these `power and torque`-related dimensions.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_power_torque = cars[['power_rpm', 'power_ps', 'torque_rpm', 'torque_nm']].corr()

# Display the correlation matrix
correlation_matrix_power_torque
# Out:
#             power_rpm  power_ps  torque_rpm  torque_nm
# power_rpm       1.000     0.064       0.282     -0.067
# power_ps        0.064     1.000       0.244      0.855
# torque_rpm      0.282     0.244       1.000     -0.072
# torque_nm      -0.067     0.855      -0.072      1.000

# %% [markdown]
# **Observation:**<br>
# Indian Dads are less interested in this! Why did I find this even?<br> Its a more genz matter.

# %% [markdown]
# In this part, we choose specific columns related to `gears`, `doors`, and additional `features` from the '`cars`' DataFrame and compute the correlation matrix.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_gears_doors_features = cars[['gears', 'doors', 'num_features']].corr()

# Display the correlation matrix
correlation_matrix_gears_doors_features
# Out:
#               gears  doors  num_features
# gears         1.000 -0.212         0.506
# doors        -0.212  1.000        -0.176
# num_features  0.506 -0.176         1.000

# %% [markdown]
# **Observation:**<br>
# Yes! Features, door and gears are the important factors for Indians.

# %% [markdown]
# ### 2. **Scatter Plots**

# %% [markdown]
# Here, we create a scatter plot to visualize the relationship between the `ex-showroom price` and the `number of features for each car`. The x-axis is scaled logarithmically for better clarity.

# %%
# Scatter plot of ex-showroom price vs. number of features
plt.figure(figsize=(14, 4))
plt.scatter(cars['ex-showroom_price_inr'], cars['num_features'], alpha=0.5, c='purple')
plt.title('Ex-showroom Price vs. Number of Features')
plt.xlabel('Ex-showroom Price (INR)')
plt.ylabel('Number of Features')
plt.xscale('log')
plt.grid(True)
plt.show()

# %% [markdown]
# **Observation:**<br>
# Gives an informative insight as we see the number of features are growing upto 10 Lakhs, as the customers of India prefer more features in more affordable car.

# %% [markdown]
# The plots include comparisons between car `make` and `ex-showroom price`, `ARAI certified mileage` and `fuel type`, `fuel type` and `cylinder configuration`, and `fuel type` and `car type`. Legends and log scale on the y-axis are applied for better visualization.

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Scatter plot between car make and ex-showroom price
sns.scatterplot(x='make', y='ex-showroom_price_inr', data=cars, palette='viridis', ax=axs[0, 0])
axs[0, 0].set_title('Car Make vs Ex-showroom Price')
axs[0, 0].set_xlabel('Car Make')
axs[0, 0].set_ylabel('Ex-showroom Price (INR)')
axs[0, 0].set_yscale('log')
axs[0, 0].tick_params(axis='x', rotation=90,labelsize=8)

# Scatter plot between ARAI certified mileage and fuel type
sns.scatterplot(x='arai_certified_mileage_kmpl', y='fuel_type', data=cars, hue='fuel_type', palette='viridis', ax=axs[0, 1])
axs[0, 1].set_title('ARAI Certified Mileage vs Fuel Type')
axs[0, 1].set_xlabel('ARAI Certified Mileage (kmpl)')
axs[0, 1].set_ylabel('Fuel Type')
axs[0, 1].legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Scatter plot between fuel type and cylinder configuration
sns.scatterplot(x='fuel_type', y='cylinder_configuration', data=car_no_unspecified, hue='fuel_type', palette='viridis', ax=axs[1, 0])
axs[1, 0].set_title('Fuel Type vs Cylinder Configuration')
axs[1, 0].set_xlabel('Fuel Type')
axs[1, 0].set_ylabel('Cylinder Configuration')
axs[1, 0].legend(title='Fuel Type')

# Scatter plot between fuel type and car type
sns.scatterplot(x='fuel_type', y='type', data=car_no_unspecified, hue='fuel_type', palette='viridis', ax=axs[1, 1])
axs[1, 1].set_title('Fuel Type vs Car Type')
axs[1, 1].set_xlabel('Fuel Type')
axs[1, 1].set_ylabel('Car Type')
axs[1, 1].legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\1118596458.py:4: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.

# %% [markdown]
# **Observation:**<br>
# 1. Tata, Maruti, Hundai, Mahindra, Kia, Bajaj and Honda provides the afforadable cars focusing more customer.
# 2. CNG provides really good mileage as compare petrol and diesel.
# 3. In-line transmission supports all fuel type, making it more universal. V type is for sports
# 4. Never knew that manual isn't adjustable with electric. Also Automatic isn't adjustable with CNG.

# %% [markdown]
# ### 3. **Pair Plots**

# %% [markdown]
# We create a pairplot to visualize relationships between selected numeric variables (`height`, `length`, `width`, `kerb weight`, and `ground clearance`) in the '`cars`' DataFrame. The data is `subsampled` to improve **plot readability**. The title is added for clarity.

# %%
# Pairplot for selected numeric variables
selected_numeric_variables = ['height_mm', 'length_mm', 'width_mm', 'kerb_weight_kg', 'ground_clearance_mm']
# Subsample the data
subsampled_data = cars.sample(frac=0.2, random_state=42)

# Pairplot for selected numeric variables with subsampled data
sns.pairplot(subsampled_data[selected_numeric_variables])
plt.suptitle('Pairplot of Selected Numeric Variables (Subsampled Data)', y=1.02)
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# ...

# %% [markdown]
# **Observation:**<br>
# Pairplots give an insight of the dimensions that one looks before buying, to save taxes.

# %% [markdown]
# To visualize relationships between selected `power` and `torque` variables (`power RPM`, `power PS`, `torque RPM`, and `torque NM`) in the '`cars`' DataFrame. The title is included for clarity.

# %%
# Selected numeric variables
selected_power_torque_variables = ['power_rpm', 'power_ps', 'torque_rpm', 'torque_nm']

# Pairplot for selected power and torque variables
sns.pairplot(cars[selected_power_torque_variables])
plt.suptitle('Pairplot of Power and Torque Variables', y=1.02)
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# **Observation:**<br>
# Pairplot for the car lovers, to compare the power and torque then, buy the best car.

# %% [markdown]
# ### 4. **Bar Charts**

# %% [markdown]
# Reference: [pd.cut](https://www.geeksforgeeks.org/pandas-cut-method-in-python/)

# %% [markdown]
# To explore the relationship between the `number of features`, `price segment`, and specific car `models`. The first chart displays the `count` of cars based on the number of `features and price segment`. The second and third charts showcase the `top 5 expensive` and `cheapest` car models along with the corresponding number of features. Legends, titles, and axis labels are provided for better interpretation.

# %%
# Create bins for the number of features
feature_bins = [0, 10, 20, 30, 40, float('inf')]
feature_labels = ['0-10', '11-20', '21-30', '31-40', '41+']
cars['feature_bins'] = pd.cut(cars['num_features'], bins=feature_bins, labels=feature_labels, right=False)

# Find the top 5 unique car models with the highest ex-showroom prices
top_expensive_models = cars.sort_values(by='ex-showroom_price_inr', ascending=False).drop_duplicates(subset='model').head(5)

# Find the top 5 unique car models with the lowest ex-showroom prices
top_cheapest_models = cars.sort_values(by='ex-showroom_price_inr', ascending=True).drop_duplicates(subset='model').head(5)

# Create a 1x3 matrix of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the first chart (Number of Features vs Price Segment)
sns.countplot(data=cars, x='feature_bins', hue='price_segment', palette='viridis', ax=axes[0])
axes[0].set_title('Number of Features vs Price Segment')
axes[0].set_xlabel('Number of Features')
axes[0].set_ylabel('Count')

# Plot the second chart (Top 5 Expensive Car Models vs Number of Features)
sns.barplot(data=top_expensive_models, x='model', y='num_features', palette='viridis', width=0.5 , ax=axes[1])
axes[1].set_title('Top 5 Expensive Car Models vs Number of Features')
axes[1].set_xlabel('Car Model')
axes[1].set_ylabel('Number of Features')
axes[1].tick_params(axis='x', rotation=45)

# Plot the third chart (Top 5 Cheapest Car Models vs Number of Features)
sns.barplot(data=top_cheapest_models, x='model', y='num_features', palette='viridis', width=0.5, ax=axes[2])
axes[2].set_title('Top 5 Cheapest Car Models vs Number of Features')
axes[2].set_xlabel('Car Model')
axes[2].set_ylabel('Number of Features')
axes[2].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\600282316.py:4: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# **Observation:**<br>
# 1. Seems like that affordable cars provide more features, however super expensive car provides more power.
# 2. Chiron provides most feature and cullinan with least feature, being super expensive.
# 3. Nano Genx and Kwid are quiet impressive to provide such great features even being cheap.

# %% [markdown]
# Here, we sort the data by the mean mileage in descending order and create a bar chart to compare the `ARAI certified mileage` mean across different `fuel types`.

# %%
# Sort the data by mean mileage in descending order
sorted_data = cars.groupby('fuel_type')['arai_certified_mileage_kmpl'].mean().sort_values(ascending=False).index

# Bar chart with hue for Fuel Type vs Mileage mean
plt.figure(figsize=(14, 4))
sns.barplot(data=cars, x='fuel_type', y='arai_certified_mileage_kmpl', hue='fuel_type', ci=False, palette='viridis', dodge=False, order=sorted_data, width=0.5)
plt.title('Fuel Type vs Mileage Mean')
plt.xlabel('Fuel Type')
plt.ylabel('ARAI Certified Mileage (kmpl)')
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
plt.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\54871691.py:6: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.

# %% [markdown]
# **Observation:**<br>
# Some one please call and make Indian Dads undertand to buy CNG cars.

# %% [markdown]
# Now we explore the relationships between selected `body types`, `wheelbase`, `ARAI certified mileage`, and `ex-showroom price`. Three bar charts are created, each focusing on a different aspect and displaying the mean values.

# %%
# Define the desired body types
desired_body_types = ['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV']

# Filter the DataFrame to include only the desired body types
filtered_car = cars[cars['body_type'].isin(desired_body_types)]

# Order the body types by mean wheelbase in descending order
order_body_types_wheelbase = filtered_car.groupby('body_type')['wheelbase_mm'].mean().sort_values(ascending=False).index

# Order the body types by mean ARAI Certified Mileage in descending order
order_body_types_mileage = filtered_car.groupby('body_type')['arai_certified_mileage_kmpl'].mean().sort_values(ascending=False).index

# Order the body types by mean Ex-showroom Price in descending order
order_body_types_price = filtered_car.groupby('body_type')['ex-showroom_price_inr'].mean().sort_values(ascending=False).index

# Create a 1x3 matrix for the subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Bar chart with hue for Wheel Size vs Body Type
sns.barplot(ax=axes[0], data=filtered_car, x='wheelbase_mm', y='body_type', hue='body_type', ci=False, palette='viridis', dodge=False, order=order_body_types_wheelbase)
axes[0].set_title('Wheel Size vs Body Type')
axes[0].set_xlabel('Wheelbase (mm)')
axes[0].set_ylabel('Body Type')
axes[0].legend(loc='lower right', bbox_to_anchor=(1.0, 0.0))

# Bar chart for Body Type vs ARAI Certified Mileage mean
sns.barplot(ax=axes[1], data=filtered_car, x='arai_certified_mileage_kmpl', y='body_type', hue='body_type', ci=False, palette='viridis', dodge=False, order=order_body_types_mileage)
axes[1].set_title('Body Type vs ARAI Certified Mileage Mean')
axes[1].set_xlabel('ARAI Certified Mileage (kmpl)')
axes[1].set_ylabel('Body Type')
axes[1].legend(loc='lower right', bbox_to_anchor=(1.0, 0.0))

# Bar chart for Body Type vs Ex-showroom Price mean with log scale on x-axis
sns.barplot(ax=axes[2], data=filtered_car, x='ex-showroom_price_inr', y='body_type',hue='body_type', ci=False, palette='viridis', dodge=False, order=order_body_types_price)
axes[2].set_xscale('log')
axes[2].set_title('Body Type vs Ex-showroom Price Mean')
axes[2].set_xlabel('Ex-showroom Price (INR)')
axes[2].set_ylabel('Body Type')
axes[2].legend(loc='lower right', bbox_to_anchor=(1.0, 0.0))

# Adjust layout to prevent clipping of titles
plt.tight_layout()
plt.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\1568169483.py:20: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\1568169483.py:27: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\1568169483.py:34: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.

# %% [markdown]
# **Observation:**<br>
# 1. Hatch back, Crossover and MPV is used for comfort/daily riding, however sport and SUV and pickup are heavy duty cars, that require more grip on road.
# 2. Sports having fastest engine, consumes fiul faster as compared to crossover being used for comfort ride.
# 3. Sports car having costliest engine tends to be more expensive.

# %% [markdown]
# ### 5. **Heatmaps**

# %% [markdown]
# Here, we choose specific `dimensions` from the '`cars`' DataFrame and compute the correlation matrix. The resulting heatmap visually represents the correlation coefficients between these dimension variables.

# %%
# Select the dimensions and calculate the correlation matrix
dimension_subset = cars[['height_mm', 'length_mm', 'width_mm', 'kerb_weight_kg', 'ground_clearance_mm']].corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(dimension_subset, annot=True, cmap='crest', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap for Dimension Variables')
plt.show()

# %% [markdown]
# **Observation:**<br>
# Dimesions of car that is really required

# %% [markdown]
# Now we focus on specific `tire-related variables` by selecting columns from the '`cars`' DataFrame. The resulting heatmap illustrates the correlation coefficients among these tire-related dimensions, providing insights into their relationships.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_tire = cars[['front_track_mm', 'rear_track_mm', 'f_tire_diameter_inch', 'f_tire_aspect_ratio',
                               'f_tire_width_mm', 'r_tire_diameter_inch', 'r_tire_aspect_ratio', 'r_tire_width_mm']].corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_tire, annot=True, cmap='crest', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap for Tire-related Variables')
plt.show()

# %% [markdown]
# **Observation:**<br>
# Tires also matter for the roads full of potholes.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_power_torque = cars[['power_rpm', 'power_ps', 'torque_rpm', 'torque_nm']].corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix_power_torque, annot=True, cmap='crest', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap for Power and Torque Variables')
plt.show()

# %% [markdown]
# **Observation:**<br>
# Indian Dads are less interested in this! Why did I find this even?<br> Its a more genz matter.

# %% [markdown]
# In this section, we focus on specific `power` and `torque` variables by selecting columns from the '`cars`' DataFrame. The resulting heatmap illustrates the correlation coefficients among these variables, providing insights into their relationships.

# %%
# Select the specified columns and calculate the correlation matrix
correlation_matrix_gears_doors_features = cars[['gears', 'doors', 'num_features']].corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix_gears_doors_features, annot=True, cmap='crest', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap for Gears, Doors, and Num Features')
plt.show()

# %% [markdown]
# **Observation:**<br>
# Yes! Features, door and gears are the important factors for Indians.

# %% [markdown]
# ### 6. **Joint Plots**

# %% [markdown]
# Now we explore the relationships between the logarithm of `ex-showroom price`, `ARAI certified mileage`, and `body type` for the `desired body types`. The joint plot visualizes these correlations.

# %%
# Define the desired body types
desired_body_types = ['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV']

# Filter the DataFrame to include only the desired body types
filtered_car = cars[cars['body_type'].isin(desired_body_types)]

# Joint plot for Price vs Mileage vs Body type
plt.figure(figsize=(8, 6))
filtered_car['log_price'] = np.log1p(filtered_car['ex-showroom_price_inr'])

joint_plot = sns.jointplot(data=filtered_car, x='log_price', y='arai_certified_mileage_kmpl', hue='body_type', height=8)
joint_plot.set_axis_labels('Log(Ex-showroom Price) INR', 'ARAI Certified Mileage (kmpl)')
joint_plot.fig.suptitle('Joint Plot for Log(Price) vs Mileage vs Body Type', y=1.02)
plt.show()

# Remove the temporary log_price column
filtered_car.drop('log_price', axis=1, inplace=True)
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\3122198268.py:9: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\varun\AppData\Local\Temp\ipykernel_14200\3122198268.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# ...

# %% [markdown]
# **Observation:**<br>
# Gives a brief idea that bigger bodytype consumes more fuel.

# %% [markdown]
# Here, we generate a joint plot to explore the relationships between car `length` and `width`, considering different `fuel types`. The plot provides insights into how these dimensions vary across various fuel types.

# %%
# Joint plot for Length vs Width vs Fuel type
plt.figure(figsize=(12, 8))

joint_plot = sns.jointplot(data=cars, x='length_mm', y='width_mm', hue='fuel_type', height=8)
joint_plot.set_axis_labels('Length (mm)', 'Width (mm)')
joint_plot.fig.suptitle('Joint Plot for Length vs Width vs Fuel Type', y=1.02)
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# **Observation:**<br>
# Gives synopsis about the dimension that requires to carry various types of fuel.

# %% [markdown]
# ### 7. **Box Plots**

# %% [markdown]
# Here, we use a 2x2 matrix of subplots to **compare different aspects** of car data. We explore `affordability` vs `price`, `fuel type` vs `mileage`, `body type` vs `doors`, and `wheel size` vs `minimum turning radius`.

# %%
# Create a 2x2 matrix of subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 12))

desired_body_types = ['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV']

# Filter the DataFrame to include only the desired body types
filtered_car = cars[cars['body_type'].isin(desired_body_types)]

# Order the body types by mean wheelbase in descending order
order_body_types_wheelbase = filtered_car.groupby('body_type')['wheelbase_mm'].mean().sort_values(ascending=False).index

# 1. Affordable vs Price (in log)
sns.boxplot(data=cars, x='price_segment', y=np.log1p(cars['ex-showroom_price_inr']), hue='price_segment', palette='viridis', dodge=False, ax=axes[0, 0])
axes[0, 0].set_title('Affordable vs Price (in log)')
axes[0, 0].set_xlabel('Affordability')
axes[0, 0].set_ylabel('Log(Ex-showroom Price)')

# 2. Fuel Type vs Mileage
sns.boxplot(data=cars, x='fuel_type', y='arai_certified_mileage_kmpl', hue='fuel_type', palette='viridis', dodge=False, ax=axes[0, 1])
axes[0, 1].set_title('Fuel Type vs Mileage')
axes[0, 1].set_xlabel('Fuel Type')
axes[0, 1].set_ylabel('ARAI Certified Mileage (kmpl)')

# 3. Body Type vs Doors (corrected line)
sns.boxplot(data=filtered_car, x='body_type', y='doors', hue='body_type', palette='viridis', dodge=False, ax=axes[1, 0])
axes[1, 0].set_title('Body Type vs Doors')
axes[1, 0].set_xlabel('Body Type')
axes[1, 0].set_ylabel('Number of Doors')

# 4. Wheel Size vs minimum_turning_radius_meter (with y-axis in log scale)
sns.boxplot(data=cars, x='f_tire_diameter_inch', y='minimum_turning_radius_meter', hue='f_tire_diameter_inch', palette='viridis', dodge=False, ax=axes[1, 1])
axes[1, 1].set_title('Wheel Size vs Minimum Turning Radius (meters)')
axes[1, 1].set_xlabel('Front Tire Diameter (inch)')
axes[1, 1].set_ylabel('Minimum Turning Radius (meters)')
axes[1, 1].set_yscale('log')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# **Observation:**<br>
# 1. Price segment provide crisp data about the affordability of any car.
# 2. All segments of fuel type tend to have same mileage. (less outliers)
# 3. Number of doors are more or less same for every bodytype car in India, however there are 4 door super cars along with 2 door super cars as well.
# 4. Tire size seems to have same turning radius except for some outliers.

# %% [markdown]
# ### 8. **Categorical Plots**

# %% [markdown]
# Here, we use a 3x2 matrix of subplots to display categorical plots. The plots include counts of cars by `body type`, `number of doors`, `number of gears`, `affordability` vs `price`, `fuel type`, and `engine type`.

# %%
# Create a 3x2 matrix for categorical plots
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

desired_body_types = ['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV']

# Filter the DataFrame to include only the desired body types
filtered_car = cars[cars['body_type'].isin(desired_body_types)]

# Order the body types by mean count in descending order
order_body_types_count = filtered_car['body_type'].value_counts().sort_values(ascending=False).index

# Plot 1: Body Type
sns.countplot(data=filtered_car, x='body_type', palette='viridis', order=order_body_types_count, width=0.5, ax=axes[0, 0])
axes[0, 0].set_title('Count of Cars by Body Type')
axes[0, 0].set_xlabel('Body Type')
axes[0, 0].set_ylabel('Count')

# Plot 2: Doors
sns.countplot(data=cars, x='doors', palette='viridis', order=cars['doors'].value_counts().sort_values(ascending=False).index, width=0.5, ax=axes[0, 1])
axes[0, 1].set_title('Count of Cars by Number of Doors')
axes[0, 1].set_xlabel('Number of Doors')
axes[0, 1].set_ylabel('Count')
axes[0, 1].set_yscale('log')

# Plot 3: Gears
sns.countplot(data=cars, x='gears', palette='viridis', order=cars['gears'].value_counts().sort_values(ascending=False).index, width=0.5, ax=axes[1, 0])
axes[1, 0].set_title('Count of Cars by Number of Gears')
axes[1, 0].set_xlabel('Number of Gears')
axes[1, 0].set_ylabel('Count')
axes[1, 0].set_yscale('log')

# Plot 4: Affordability vs Price
sns.countplot(data=cars, x='price_segment', order=cars['price_segment'].value_counts().sort_values(ascending=False).index, width=0.5, palette='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Count of Cars by Affordability')
axes[1, 1].set_xlabel('Affordability')
axes[1, 1].set_ylabel('Count')
axes[1, 1].set_yscale('log')

# Plot 5: Fuel Type
sns.countplot(data=cars, x='fuel_type', palette='viridis', order=cars['fuel_type'].value_counts().sort_values(ascending=False).index, width=0.5, ax=axes[2, 0])
axes[2, 0].set_title('Count of Cars by Fuel Type')
axes[2, 0].set_xlabel('Fuel Type')
axes[2, 0].set_ylabel('Count')
axes[2, 0].set_yscale('log')

# Plot 6: Engine Type
sns.countplot(data=car_no_unspecified, x='cylinder_configuration', palette='viridis', order=car_no_unspecified['cylinder_configuration'].value_counts().sort_values(ascending=False).index, width=0.5, ax=axes[2, 1])
axes[2, 1].set_title('Count of Cars by Engine Type')
axes[2, 1].set_xlabel('Engine Type')
axes[2, 1].set_ylabel('Count')
axes[2, 1].set_yscale('log')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# **Observation:**<br>
# 1. OK! I understand SUV is more in India. Pick up is merely there in India.
# 2. Most Indian cars have 5 doors.
# 3. Indians loveeeeeee 5 gear manual than their car!
# 4. Indian market is booming with affordable cars.
# 5. Ok I understand, we need to become Indian Dads to make CNG popular.
# 6. In-line is most affordable and popular type in India

# %% [markdown]
# ### 9. **Violin Plots**

# %% [markdown]
# This code generates a Violin Plot to visualize the distribution of `ex-showroom prices` for the `top 5 car makes` based on **average prices**.

# %%
# Get the top 5 car makes based on average ex-showroom price
top_5_makes = cars.groupby('make')['ex-showroom_price_inr'].mean().sort_values(ascending=False).head(5).index

# Filter the dataset for the top 5 makes
top_5_car_makes_data = cars[cars['make'].isin(top_5_makes)]

# Create a Violin Plot with y-axis limit
plt.figure(figsize=(15, 5))
sns.violinplot(data=top_5_car_makes_data, x='make', y='ex-showroom_price_inr', palette='viridis')
plt.title('Violin Plot of Ex-showroom Prices for Top 5 Car Makes')
plt.xlabel('Car Make')
plt.ylabel('Ex-showroom Price (INR)')
plt.show()

# %% [markdown]
# **Observation:**<br>
# Well, Lamborghini has more diverse variants than bugatti being more diverse in pricing. <br> Why am I making it? I don't even have the money to buy my own cycle.

# %% [markdown]
# Violin Plot to visualize the distribution of `ARAI certified mileage` for different `fuel types`. The plot provides insights into the mileage distribution and helps in comparing the **fuel efficiency** of various fuel types.

# %%
# Create a Violin Plot for Fuel Type vs Mileage
plt.figure(figsize=(12, 8))
sns.violinplot(data=cars, x='fuel_type', y='arai_certified_mileage_kmpl', palette='viridis')
plt.title('Violin Plot of ARAI Certified Mileage by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('ARAI Certified Mileage (kmpl)')
plt.show()

# %% [markdown]
# **Observation:**<br>
# CNG Provides more mileage range, Petrol and Diesel are providing less mileage ranges

# %% [markdown]
# ### 10. **Stacked Bar Charts**

# %% [markdown]
# We sort the fuel types in **descending order** and create a stacked bar chart illustrating the distribution of `price segments` across different `fuel types`. The bars are sorted in decreasing order based on their total count.

# %%
# Sort fuel types in descending order
sorted_fuel_types = sorted(cars['fuel_type'].unique(), reverse=True)

# Create a stacked bar chart for Price Segment vs Fuel Type using Plotly
fig = px.histogram(cars, x='fuel_type', color='price_segment', barmode='stack',
                   category_orders={'fuel_type': sorted_fuel_types},
                   labels={'fuel_type': 'Fuel Type', 'price_segment': 'Price Segment'},
                   title='Price Segment Distribution by Fuel Type')


fig.update_layout(xaxis_title='Fuel Type', yaxis_title='Count (log scale)', legend_title='Price Segment', yaxis_type="log")
# Sort bars in decreasing order
fig.update_xaxes(categoryorder='total descending')

fig.show()
# Out:
# c:\Users\varun\anaconda3\Lib\site-packages\plotly\express\_core.py:1958: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# **Observation:**<br>
# Hybrid cars are super expensive everytime. Petrol and Diesel are more focused to be pocket friendly

# %% [markdown]
# We filter the dataset for `desired body types` and create a stacked bar chart to represent the `distribution of car makes` within these body types. The chart provides insights into the variety of car makes present in the specified body types.

# %%
# Filter the dataset for desired body types
filtered_car = cars[cars['body_type'].isin(['Coupe', 'Crossover', 'Hatchback', 'MPV', 'MUV', 'Pick-up', 'Sedan', 'Sports', 'SUV'])]

# Create a stacked bar chart for Make vs Desired Body Types using Plotly
fig = px.histogram(filtered_car, x='make', color='body_type', barmode='stack',
                   category_orders={'make': sorted(filtered_car['make'].unique(), reverse=True)},
                   labels={'make': 'Make', 'body_type': 'Body Type'},
                   title='Make Distribution by Desired Body Types')
fig.update_layout(xaxis_title='Make', yaxis_title='Count', legend_title='Body Type')
fig.update_xaxes(tickangle=45, tickmode='array', tickvals=filtered_car['make'].unique())
fig.show()

# %% [markdown]
# **Observation:**<br>
# Maruti, Mahindra and Hyundai provides extensive number of Body type cars to Indian Market.

# %% [markdown]
# Here, we filter out '`unspecified`' values from the '`cylinder_configuration`' column and create a stacked bar chart. The chart depicts the `distribution of fuel types` across different cylinder configurations, providing insights into the variety of engines in the dataset.

# %%
# Filter out 'unspecified' values from cylinder_configuration
filtered_car = cars[cars['cylinder_configuration'] != 'unspecified']

# Sort fuel types in descending order
sorted_fuel_types = sorted(filtered_car['fuel_type'].unique(), reverse=True)

# Create a stacked bar chart for Fuel Type vs Cylinder using Plotly
fig = px.histogram(filtered_car, x='fuel_type', color='cylinder_configuration', barmode='stack',
                   category_orders={'fuel_type': sorted_fuel_types},
                   labels={'fuel_type': 'Fuel Type', 'cylinder_configuration': 'Cylinder Configuration'},
                   title='Fuel Type Distribution by Cylinder Configuration')


fig.update_layout(xaxis_title='Fuel Type', yaxis_title='Count (log scale)', legend_title='Cylinder Configuration', yaxis_type="log")
# Sort bars in decreasing order
fig.update_xaxes(categoryorder='total descending')

fig.show()

# %% [markdown]
# **Observation:**<br>
# Petrol is the only fuel type that can run on all 4 cylinder types.

# %% [markdown]
# Dropping the extra columns generated during the process of visualization.

# %%
# Drop 'feature_bins' and 'log_price' columns
cars = cars.drop(['feature_bins'], axis=1)
cars
# Out:
#             make      model        variant  ex-showroom_price_inr  \
# 0           Tata  Nano Genx             Xt                 292667
# 1           Tata  Nano Genx             Xe                 236447
# 2           Tata  Nano Genx        Emax Xm                 296661
# 3           Tata  Nano Genx            Xta                 334768
# 4           Tata  Nano Genx             Xm                 272223
# ...          ...        ...            ...                    ...
# 1271       Honda       City   Vx Mt Diesel                1302000
# 1272       Honda       City   Zx Mt Diesel                1421000
# 1273       Honda       City  Zx Cvt Petrol                1431000
# 1274       Honda       City   V Cvt Petrol                1201000
# 1275  Mitsubishi    Montero         3.2 At                6862560
#
#       displacement_cc  cylinders  valves_per_cylinder drivetrain  \
# 0             624.000      2.000                2.000       RWD
# ...

# %% [markdown]
# **Observation:**<br>
# 1. Due to even terrains (except pothholes), all cars are suitable to use Forward and Rear wheel drive.
# 2. Petrol and Diesel dominates Indian market
# 3. Most cars in India are required for city drive, they are rarely used for long drives. In-line is most suitable cylinder.
# 4. Almost every affordable car got their engine located in front.
# 5. 5 doors ? Really ? I think they are counting the trunk.
# 6. Most manual cars use 5 Geared transmission.
# 7. Slowly the automatic transmission is rising, which shows that Indian people are lazy to hit the clutch even.
# 8. Is SUV the new hatchback? Interesting!

# %% [markdown]
# **Observation:**<br>
# 1. Yes, prices of car, have extensive outliers depending of rich class of people buying super expensive sports or luxury cars.
# 2. An average car in India gives mileage of 17-22 kmpl.
# 3. Cylinders of Indian cars remain fixed and distributed.
# 4. Most car of India has 4 doors except the sports car having 2 doors.
